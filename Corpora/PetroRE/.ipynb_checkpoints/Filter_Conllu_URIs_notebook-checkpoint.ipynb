# %% [markdown]
# # Notebook para filtrar o arquivo conllu em sentenças que contenham pelo menos duas URIS anotadas

# %%
import argparse
import json
from conllu import parse
import pandas as pd
from conllu import parse_incr
import pickle
import numpy as np
import re
import os
import unicodedata
import numpy as np

# %% [markdown]
# ### Funções

# %%
#utils
def ents_uris_counter_prefiltering(sentence,ents,uris): #contagem de entidades e uris pre-filtragem
    entidades_sentenca_old = ents
    uris_sentenca_old = uris
    ents_list = ents
    uris_list = uris
    if sentence.iloc[0]["misc"].get('eliminar') == '':#retirar linha com eliminar
        print('ELIMINADA')
        return 0, entidades_sentenca_old, uris_sentenca_old   
    for idx_row in range(0,len(sentence)):
        if sentence.iloc[idx_row]['misc'].get('start_char') == None:#problema com start_char
            return 0, entidades_sentenca_old, uris_sentenca_old
        token = sentence.iloc[idx_row]['deps']
        grafo = sentence.iloc[idx_row]['misc'].get('grafo')
        if "B=" in token:
            ents_list.append(token)
        if grafo:
            uris_list.append(grafo)     
    return 1, ents_list, uris_list

def check_sentence_for_uris(sentence, ents, uris): #funcao que conta quantas URIS tem dentro da sentenca
    entidades_sentenca_old = ents
    uris_sentenca_old = uris
    ents_list = ents
    uris_list = uris
    countURIs = 0 
    if sentence.iloc[0]["misc"].get('eliminar') == '':#retirar linha com eliminar
        print('eliminada')
        return 0, entidades_sentenca_old, uris_sentenca_old 
    for idx_row in range(0,len(sentence)):
        if sentence.iloc[idx_row]['misc'].get('start_char') == None:#problema com start_char
            print('start_char com problema')
            return 0, entidades_sentenca_old, uris_sentenca_old
        token = sentence.iloc[idx_row]['deps']
        grafo = sentence.iloc[idx_row]['misc'].get('grafo')
        if "B=" in token and grafo: 
            ents_list = ents_list + [token]
            uris_list = uris_list + [grafo]
            countURIs += 1
    if countURIs > 1: #tem no minimo 2 entidades com URI
        return 1, ents_list, uris_list
    return 0, entidades_sentenca_old, uris_sentenca_old

def get_start(x, offset):
    start = str(int(x["start_char"]) - offset)
    return start
def get_end(x, offset):
    end = str(int(x["end_char"]) - offset)
    return end

# %% [markdown]
# ## Ler conllu para filtrar sentencas que contenham pelo menos duas URIs

# %%
CONLLU_PATH = "..\PetroNER\petroner-uri-2023-04-05.conllu"
data_file = open(CONLLU_PATH, "r", encoding="utf-8")
sentences=[]
for tokenlist in parse_incr(data_file):
    sentences.append(tokenlist)
print('Total number of sentences in conllu ->',len(sentences))
# Out:
# Total number of sentences in conllu -> 24035

# %%
#algum problema nessas sentencas em diferentes petroner
sentences_with_issues = [12408, 13636, 15264, 21023, 21122, 23920, 24017]
# sentences_with_issues = [1749, 4747, 4935, 5066, 5235, 5798, 6802, 7858, 8881, 9271, 10689, 10691, 10695, 10750, 
#                          11144, 12408, 13393, 13636, 15264, 17494, 18462, 18476, 19346, 21023, 21105, 21122, 
#                         22163, 23920, 24017]

# %% [markdown]
# ## Rotina para contar entidades e URIs no conllu

# %%
ents_pre = []
uris_pre = []
for idxGroups in range(0,len(sentences)):
    if idxGroups not in sentences_with_issues: 
        
        #print('sentence = ' ,idxGroups)
        sentence = sentences[idxGroups]
        json_temp = json.dumps(sentence)
        df_get_start_end = pd.read_json(json_temp)

        df_get_start_end = df_get_start_end[df_get_start_end['misc'].notna()]
        df_get_start_end = df_get_start_end.reset_index(drop=True)
        df_get_start_end = df_get_start_end[df_get_start_end['deps'].notna()]
        df_get_start_end = df_get_start_end.reset_index(drop=True)
        
        checkQtdTokenURI, ents_pre, uris_pre = ents_uris_counter_prefiltering(df_get_start_end,ents_pre,uris_pre)
        
entidades_pre, numb_ents_pre = np.unique(ents_pre, return_counts = True)
grafos_pre, numb_grafos_pre = np.unique(uris_pre, return_counts = True)
print('------------')
print('lista de diferentes tipos de entidades no conllu')
print(entidades_pre.tolist())
print('------------')
print('quantidades de diferentes tipos de entidades no conllu')
print(numb_ents_pre.tolist())
print('------------')
print('Total de URIs no Conllu original ->',sum(numb_grafos_pre.tolist()))
# Out:
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ELIMINADA
# ------------
# lista de diferentes tipos de entidades no conllu
# ['B=BACIA', 'B=CAMPO', 'B=ESTRUTURA_FÍSICA', 'B=EVENTO_PETRO', 'B=FLUIDO', 'B=FLUIDODATERRA_i', 'B=FLUIDODATERRA_o', 'B=NÃOCONSOLID', 'B=POÇO', 'B=POÇO_Q', 'B=POÇO_R', 'B=POÇO_T', 'B=ROCHA', 'B=TEXTURA', 'B=TIPO_POROSIDADE', 'B=UNIDADE_CRONO', 'B=UNIDADE_LITO']
# ------------
# quantidades de diferentes tipos de entidades no conllu
# [3992, 702, 2029, 492, 174, 1372, 245, 1035, 1200, 9, 3, 35, 2768, 140, 22, 2907, 1486]
# ------------
# Total de URIs no Conllu original -> 17944

# %% [markdown]
# ## Rotina para filtrar o arquivo conllu

# %%
df_filtred = pd.DataFrame()
contSentences = 0
ents = []
uris = []
for idxGroups in range(0,len(sentences)):
    if idxGroups not in sentences_with_issues:
        #print('sentence = ' ,idxGroups)
        sentence = sentences[idxGroups]
        json_sent = json.dumps(sentence)
        df_sentence = pd.read_json(json_sent)
        
        #retira tokens nulos na sentenca
        df_sentence = df_sentence[df_sentence['misc'].notna()]
        df_sentence = df_sentence.reset_index(drop=True)
        df_sentence = df_sentence[df_sentence['deps'].notna()]
        df_sentence = df_sentence.reset_index(drop=True)

        #checa se a sentenca tem minimo de 2 URIs
        checkQtdTokenURI, ents, uris = check_sentence_for_uris(df_sentence,ents,uris)
        if checkQtdTokenURI == 1:
            contSentences+= 1
            #arruma o offset nas colunas 'start' e 'end'
            offset = int(df_sentence.iloc[0]["misc"].get("start_char"))
            df_sentence['start'] = df_sentence['misc'].apply(lambda x: get_start(x, offset))
            df_sentence['end'] = df_sentence['misc'].apply(lambda x: get_end(x, offset))

            df_sentence['sentence'] = contSentences
            df_sentence['#sentence_original'] = idxGroups
            print('sentences after filtering ->', contSentences)
            df_filtred = pd.concat([df_filtred, df_sentence ])
            
#salvar o dataframe com as sentencas ja filtradas em arquivo .pkl                   
pickle.dump(df_filtred, open('df_filtred_petroner_uri_2023_04_05.conllu.pkl', 'wb'), protocol=pickle.HIGHEST_PROTOCOL)
df_filtred.to_csv('df_filtred_petroner_uri_2023_04_05_conllu.csv',encoding = 'utf-8',index=False)

#entidades é a lista de diferentes tipos de entidades que aparecem após filtragem das sentencas
entidades, numb_ents = np.unique(ents, return_counts = True)
#grafos é a lista de diferentes URIs anotadas que aparecem após filtragem das sentencas
grafos, numb_grafos = np.unique(uris, return_counts = True)
print('------------')
print('lista de diferentes tipos de entidades pós filtragem')
print(entidades.tolist())
print('------------')
print('quantidades de diferentes tipos de entidades pós filtragem')
print(numb_ents.tolist())
print('------------')
print('Total de URIs pós filtragem ->', sum(numb_grafos.tolist()))
# Out:
# sentences after filtering -> 1
# eliminada
# eliminada
# sentences after filtering -> 2
# sentences after filtering -> 3
# sentences after filtering -> 4
# sentences after filtering -> 5
# sentences after filtering -> 6
# sentences after filtering -> 7
# sentences after filtering -> 8
# sentences after filtering -> 9
# sentences after filtering -> 10
# sentences after filtering -> 11
# sentences after filtering -> 12
# sentences after filtering -> 13
# sentences after filtering -> 14
# sentences after filtering -> 15
# sentences after filtering -> 16
# sentences after filtering -> 17
# sentences after filtering -> 18
# sentences after filtering -> 19
# sentences after filtering -> 20
# sentences after filtering -> 21
# sentences after filtering -> 22
# eliminada
# sentences after filtering -> 23
# sentences after filtering -> 24
# sentences after filtering -> 25
# sentences after filtering -> 26
# sentences after filtering -> 27
# sentences after filtering -> 28
# sentences after filtering -> 29
# sentences after filtering -> 30
# sentences after filtering -> 31
# sentences after filtering -> 32
# sentences after filtering -> 33
# sentences after filtering -> 34
# sentences after filtering -> 35
# sentences after filtering -> 36
# sentences after filtering -> 37
# sentences after filtering -> 38
# sentences after filtering -> 39
# sentences after filtering -> 40
# sentences after filtering -> 41
# sentences after filtering -> 42
# sentences after filtering -> 43
# sentences after filtering -> 44
# sentences after filtering -> 45
# sentences after filtering -> 46
# sentences after filtering -> 47
# sentences after filtering -> 48
# sentences after filtering -> 49
# sentences after filtering -> 50
# sentences after filtering -> 51
# sentences after filtering -> 52
# sentences after filtering -> 53
# sentences after filtering -> 54
# sentences after filtering -> 55
# sentences after filtering -> 56
# sentences after filtering -> 57
# sentences after filtering -> 58
# sentences after filtering -> 59
# sentences after filtering -> 60
# sentences after filtering -> 61
# sentences after filtering -> 62
# sentences after filtering -> 63
# sentences after filtering -> 64
# sentences after filtering -> 65
# sentences after filtering -> 66
# sentences after filtering -> 67
# sentences after filtering -> 68
# start_char com problema
# sentences after filtering -> 69
# sentences after filtering -> 70
# sentences after filtering -> 71
# sentences after filtering -> 72
# sentences after filtering -> 73
# sentences after filtering -> 74
# sentences after filtering -> 75
# sentences after filtering -> 76
# sentences after filtering -> 77
# sentences after filtering -> 78
# sentences after filtering -> 79
# sentences after filtering -> 80
# sentences after filtering -> 81
# sentences after filtering -> 82
# sentences after filtering -> 83
# sentences after filtering -> 84
# sentences after filtering -> 85
# sentences after filtering -> 86
# sentences after filtering -> 87
# sentences after filtering -> 88
# sentences after filtering -> 89
# sentences after filtering -> 90
# sentences after filtering -> 91
# sentences after filtering -> 92
# sentences after filtering -> 93
# sentences after filtering -> 94
# sentences after filtering -> 95
# sentences after filtering -> 96
# sentences after filtering -> 97
# sentences after filtering -> 98
# sentences after filtering -> 99
# sentences after filtering -> 100
# sentences after filtering -> 101
# sentences after filtering -> 102
# sentences after filtering -> 103
# sentences after filtering -> 104
# sentences after filtering -> 105
# sentences after filtering -> 106
# sentences after filtering -> 107
# sentences after filtering -> 108
# sentences after filtering -> 109
# sentences after filtering -> 110
# sentences after filtering -> 111
# sentences after filtering -> 112
# sentences after filtering -> 113
# sentences after filtering -> 114
# sentences after filtering -> 115
# sentences after filtering -> 116
# sentences after filtering -> 117
# sentences after filtering -> 118
# sentences after filtering -> 119
# sentences after filtering -> 120
# sentences after filtering -> 121
# sentences after filtering -> 122
# sentences after filtering -> 123
# sentences after filtering -> 124
# sentences after filtering -> 125
# sentences after filtering -> 126
# sentences after filtering -> 127
# sentences after filtering -> 128
# sentences after filtering -> 129
# sentences after filtering -> 130
# sentences after filtering -> 131
# sentences after filtering -> 132
# sentences after filtering -> 133
# sentences after filtering -> 134
# sentences after filtering -> 135
# eliminada
# sentences after filtering -> 136
# sentences after filtering -> 137
# sentences after filtering -> 138
# sentences after filtering -> 139
# sentences after filtering -> 140
# sentences after filtering -> 141
# sentences after filtering -> 142
# sentences after filtering -> 143
# sentences after filtering -> 144
# sentences after filtering -> 145
# sentences after filtering -> 146
# sentences after filtering -> 147
# sentences after filtering -> 148
# sentences after filtering -> 149
# sentences after filtering -> 150
# sentences after filtering -> 151
# sentences after filtering -> 152
# sentences after filtering -> 153
# sentences after filtering -> 154
# sentences after filtering -> 155
# sentences after filtering -> 156
# sentences after filtering -> 157
# sentences after filtering -> 158
# sentences after filtering -> 159
# sentences after filtering -> 160
# sentences after filtering -> 161
# sentences after filtering -> 162
# sentences after filtering -> 163
# sentences after filtering -> 164
# sentences after filtering -> 165
# sentences after filtering -> 166
# sentences after filtering -> 167
# sentences after filtering -> 168
# sentences after filtering -> 169
# sentences after filtering -> 170
# sentences after filtering -> 171
# sentences after filtering -> 172
# sentences after filtering -> 173
# sentences after filtering -> 174
# sentences after filtering -> 175
# sentences after filtering -> 176
# sentences after filtering -> 177
# sentences after filtering -> 178
# sentences after filtering -> 179
# sentences after filtering -> 180
# sentences after filtering -> 181
# sentences after filtering -> 182
# sentences after filtering -> 183
# sentences after filtering -> 184
# sentences after filtering -> 185
# sentences after filtering -> 186
# sentences after filtering -> 187
# sentences after filtering -> 188
# sentences after filtering -> 189
# sentences after filtering -> 190
# sentences after filtering -> 191
# sentences after filtering -> 192
# sentences after filtering -> 193
# sentences after filtering -> 194
# sentences after filtering -> 195
# sentences after filtering -> 196
# sentences after filtering -> 197
# sentences after filtering -> 198
# sentences after filtering -> 199
# sentences after filtering -> 200
# sentences after filtering -> 201
# sentences after filtering -> 202
# sentences after filtering -> 203
# sentences after filtering -> 204
# sentences after filtering -> 205
# sentences after filtering -> 206
# sentences after filtering -> 207
# sentences after filtering -> 208
# sentences after filtering -> 209
# start_char com problema
# eliminada
# eliminada
# eliminada
# sentences after filtering -> 210
# eliminada
# sentences after filtering -> 211
# sentences after filtering -> 212
# sentences after filtering -> 213
# sentences after filtering -> 214
# sentences after filtering -> 215
# eliminada
# sentences after filtering -> 216
# sentences after filtering -> 217
# eliminada
# sentences after filtering -> 218
# sentences after filtering -> 219
# sentences after filtering -> 220
# sentences after filtering -> 221
# sentences after filtering -> 222
# sentences after filtering -> 223
# eliminada
# sentences after filtering -> 224
# sentences after filtering -> 225
# sentences after filtering -> 226
# eliminada
# sentences after filtering -> 227
# sentences after filtering -> 228
# sentences after filtering -> 229
# sentences after filtering -> 230
# sentences after filtering -> 231
# eliminada
# sentences after filtering -> 232
# sentences after filtering -> 233
# sentences after filtering -> 234
# sentences after filtering -> 235
# sentences after filtering -> 236
# sentences after filtering -> 237
# sentences after filtering -> 238
# sentences after filtering -> 239
# sentences after filtering -> 240
# sentences after filtering -> 241
# sentences after filtering -> 242
# sentences after filtering -> 243
# sentences after filtering -> 244
# sentences after filtering -> 245
# sentences after filtering -> 246
# sentences after filtering -> 247
# sentences after filtering -> 248
# sentences after filtering -> 249
# sentences after filtering -> 250
# sentences after filtering -> 251
# sentences after filtering -> 252
# sentences after filtering -> 253
# sentences after filtering -> 254
# sentences after filtering -> 255
# sentences after filtering -> 256
# sentences after filtering -> 257
# sentences after filtering -> 258
# sentences after filtering -> 259
# sentences after filtering -> 260
# sentences after filtering -> 261
# sentences after filtering -> 262
# sentences after filtering -> 263
# sentences after filtering -> 264
# eliminada
# sentences after filtering -> 265
# sentences after filtering -> 266
# sentences after filtering -> 267
# sentences after filtering -> 268
# sentences after filtering -> 269
# sentences after filtering -> 270
# sentences after filtering -> 271
# sentences after filtering -> 272
# sentences after filtering -> 273
# sentences after filtering -> 274
# sentences after filtering -> 275
# sentences after filtering -> 276
# sentences after filtering -> 277
# sentences after filtering -> 278
# sentences after filtering -> 279
# sentences after filtering -> 280
# sentences after filtering -> 281
# sentences after filtering -> 282
# sentences after filtering -> 283
# sentences after filtering -> 284
# sentences after filtering -> 285
# sentences after filtering -> 286
# sentences after filtering -> 287
# sentences after filtering -> 288
# sentences after filtering -> 289
# sentences after filtering -> 290
# sentences after filtering -> 291
# sentences after filtering -> 292
# sentences after filtering -> 293
# sentences after filtering -> 294
# sentences after filtering -> 295
# sentences after filtering -> 296
# sentences after filtering -> 297
# sentences after filtering -> 298
# sentences after filtering -> 299
# sentences after filtering -> 300
# sentences after filtering -> 301
# sentences after filtering -> 302
# sentences after filtering -> 303
# sentences after filtering -> 304
# sentences after filtering -> 305
# sentences after filtering -> 306
# sentences after filtering -> 307
# sentences after filtering -> 308
# sentences after filtering -> 309
# sentences after filtering -> 310
# sentences after filtering -> 311
# sentences after filtering -> 312
# sentences after filtering -> 313
# sentences after filtering -> 314
# sentences after filtering -> 315
# sentences after filtering -> 316
# sentences after filtering -> 317
# sentences after filtering -> 318
# sentences after filtering -> 319
# sentences after filtering -> 320
# sentences after filtering -> 321
# sentences after filtering -> 322
# sentences after filtering -> 323
# sentences after filtering -> 324
# sentences after filtering -> 325
# sentences after filtering -> 326
# sentences after filtering -> 327
# sentences after filtering -> 328
# sentences after filtering -> 329
# sentences after filtering -> 330
# sentences after filtering -> 331
# sentences after filtering -> 332
# sentences after filtering -> 333
# sentences after filtering -> 334
# sentences after filtering -> 335
# sentences after filtering -> 336
# sentences after filtering -> 337
# sentences after filtering -> 338
# sentences after filtering -> 339
# sentences after filtering -> 340
# sentences after filtering -> 341
# sentences after filtering -> 342
# sentences after filtering -> 343
# sentences after filtering -> 344
# sentences after filtering -> 345
# sentences after filtering -> 346
# sentences after filtering -> 347
# sentences after filtering -> 348
# sentences after filtering -> 349
# sentences after filtering -> 350
# sentences after filtering -> 351
# sentences after filtering -> 352
# sentences after filtering -> 353
# sentences after filtering -> 354
# sentences after filtering -> 355
# sentences after filtering -> 356
# sentences after filtering -> 357
# sentences after filtering -> 358
# sentences after filtering -> 359
# sentences after filtering -> 360
# sentences after filtering -> 361
# sentences after filtering -> 362
# sentences after filtering -> 363
# sentences after filtering -> 364
# sentences after filtering -> 365
# sentences after filtering -> 366
# eliminada
# sentences after filtering -> 367
# sentences after filtering -> 368
# sentences after filtering -> 369
# sentences after filtering -> 370
# sentences after filtering -> 371
# sentences after filtering -> 372
# sentences after filtering -> 373
# sentences after filtering -> 374
# sentences after filtering -> 375
# sentences after filtering -> 376
# sentences after filtering -> 377
# sentences after filtering -> 378
# sentences after filtering -> 379
# sentences after filtering -> 380
# sentences after filtering -> 381
# sentences after filtering -> 382
# sentences after filtering -> 383
# sentences after filtering -> 384
# sentences after filtering -> 385
# sentences after filtering -> 386
# sentences after filtering -> 387
# sentences after filtering -> 388
# sentences after filtering -> 389
# sentences after filtering -> 390
# sentences after filtering -> 391
# sentences after filtering -> 392
# sentences after filtering -> 393
# sentences after filtering -> 394
# sentences after filtering -> 395
# sentences after filtering -> 396
# sentences after filtering -> 397
# sentences after filtering -> 398
# sentences after filtering -> 399
# sentences after filtering -> 400
# sentences after filtering -> 401
# sentences after filtering -> 402
# sentences after filtering -> 403
# sentences after filtering -> 404
# sentences after filtering -> 405
# sentences after filtering -> 406
# sentences after filtering -> 407
# sentences after filtering -> 408
# sentences after filtering -> 409
# sentences after filtering -> 410
# sentences after filtering -> 411
# sentences after filtering -> 412
# sentences after filtering -> 413
# sentences after filtering -> 414
# sentences after filtering -> 415
# sentences after filtering -> 416
# sentences after filtering -> 417
# sentences after filtering -> 418
# sentences after filtering -> 419
# sentences after filtering -> 420
# sentences after filtering -> 421
# sentences after filtering -> 422
# eliminada
# eliminada
# eliminada
# sentences after filtering -> 423
# eliminada
# eliminada
# sentences after filtering -> 424
# sentences after filtering -> 425
# sentences after filtering -> 426
# eliminada
# sentences after filtering -> 427
# sentences after filtering -> 428
# sentences after filtering -> 429
# sentences after filtering -> 430
# sentences after filtering -> 431
# sentences after filtering -> 432
# sentences after filtering -> 433
# sentences after filtering -> 434
# sentences after filtering -> 435
# sentences after filtering -> 436
# sentences after filtering -> 437
# sentences after filtering -> 438
# sentences after filtering -> 439
# sentences after filtering -> 440
# sentences after filtering -> 441
# sentences after filtering -> 442
# sentences after filtering -> 443
# sentences after filtering -> 444
# eliminada
# sentences after filtering -> 445
# sentences after filtering -> 446
# sentences after filtering -> 447
# sentences after filtering -> 448
# sentences after filtering -> 449
# sentences after filtering -> 450
# sentences after filtering -> 451
# sentences after filtering -> 452
# sentences after filtering -> 453
# sentences after filtering -> 454
# sentences after filtering -> 455
# sentences after filtering -> 456
# sentences after filtering -> 457
# sentences after filtering -> 458
# sentences after filtering -> 459
# sentences after filtering -> 460
# sentences after filtering -> 461
# eliminada
# eliminada
# sentences after filtering -> 462
# sentences after filtering -> 463
# sentences after filtering -> 464
# eliminada
# sentences after filtering -> 465
# eliminada
# sentences after filtering -> 466
# sentences after filtering -> 467
# sentences after filtering -> 468
# sentences after filtering -> 469
# sentences after filtering -> 470
# eliminada
# sentences after filtering -> 471
# eliminada
# sentences after filtering -> 472
# sentences after filtering -> 473
# sentences after filtering -> 474
# sentences after filtering -> 475
# eliminada
# sentences after filtering -> 476
# sentences after filtering -> 477
# eliminada
# sentences after filtering -> 478
# sentences after filtering -> 479
# sentences after filtering -> 480
# eliminada
# sentences after filtering -> 481
# eliminada
# sentences after filtering -> 482
# sentences after filtering -> 483
# sentences after filtering -> 484
# sentences after filtering -> 485
# sentences after filtering -> 486
# sentences after filtering -> 487
# sentences after filtering -> 488
# sentences after filtering -> 489
# sentences after filtering -> 490
# sentences after filtering -> 491
# sentences after filtering -> 492
# sentences after filtering -> 493
# sentences after filtering -> 494
# sentences after filtering -> 495
# sentences after filtering -> 496
# sentences after filtering -> 497
# sentences after filtering -> 498
# sentences after filtering -> 499
# sentences after filtering -> 500
# sentences after filtering -> 501
# sentences after filtering -> 502
# sentences after filtering -> 503
# sentences after filtering -> 504
# sentences after filtering -> 505
# sentences after filtering -> 506
# sentences after filtering -> 507
# sentences after filtering -> 508
# sentences after filtering -> 509
# eliminada
# sentences after filtering -> 510
# sentences after filtering -> 511
# sentences after filtering -> 512
# sentences after filtering -> 513
# sentences after filtering -> 514
# sentences after filtering -> 515
# sentences after filtering -> 516
# sentences after filtering -> 517
# sentences after filtering -> 518
# sentences after filtering -> 519
# sentences after filtering -> 520
# sentences after filtering -> 521
# sentences after filtering -> 522
# sentences after filtering -> 523
# eliminada
# sentences after filtering -> 524
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# sentences after filtering -> 525
# sentences after filtering -> 526
# sentences after filtering -> 527
# sentences after filtering -> 528
# sentences after filtering -> 529
# sentences after filtering -> 530
# sentences after filtering -> 531
# sentences after filtering -> 532
# sentences after filtering -> 533
# sentences after filtering -> 534
# sentences after filtering -> 535
# sentences after filtering -> 536
# sentences after filtering -> 537
# sentences after filtering -> 538
# sentences after filtering -> 539
# sentences after filtering -> 540
# sentences after filtering -> 541
# sentences after filtering -> 542
# sentences after filtering -> 543
# sentences after filtering -> 544
# sentences after filtering -> 545
# sentences after filtering -> 546
# sentences after filtering -> 547
# sentences after filtering -> 548
# sentences after filtering -> 549
# sentences after filtering -> 550
# sentences after filtering -> 551
# sentences after filtering -> 552
# sentences after filtering -> 553
# sentences after filtering -> 554
# sentences after filtering -> 555
# sentences after filtering -> 556
# sentences after filtering -> 557
# sentences after filtering -> 558
# sentences after filtering -> 559
# sentences after filtering -> 560
# sentences after filtering -> 561
# sentences after filtering -> 562
# sentences after filtering -> 563
# sentences after filtering -> 564
# sentences after filtering -> 565
# sentences after filtering -> 566
# sentences after filtering -> 567
# sentences after filtering -> 568
# sentences after filtering -> 569
# sentences after filtering -> 570
# sentences after filtering -> 571
# sentences after filtering -> 572
# sentences after filtering -> 573
# sentences after filtering -> 574
# sentences after filtering -> 575
# sentences after filtering -> 576
# sentences after filtering -> 577
# sentences after filtering -> 578
# sentences after filtering -> 579
# sentences after filtering -> 580
# sentences after filtering -> 581
# sentences after filtering -> 582
# sentences after filtering -> 583
# sentences after filtering -> 584
# sentences after filtering -> 585
# sentences after filtering -> 586
# eliminada
# sentences after filtering -> 587
# sentences after filtering -> 588
# sentences after filtering -> 589
# sentences after filtering -> 590
# sentences after filtering -> 591
# sentences after filtering -> 592
# sentences after filtering -> 593
# sentences after filtering -> 594
# sentences after filtering -> 595
# eliminada
# sentences after filtering -> 596
# eliminada
# sentences after filtering -> 597
# sentences after filtering -> 598
# sentences after filtering -> 599
# sentences after filtering -> 600
# sentences after filtering -> 601
# sentences after filtering -> 602
# sentences after filtering -> 603
# sentences after filtering -> 604
# sentences after filtering -> 605
# sentences after filtering -> 606
# sentences after filtering -> 607
# sentences after filtering -> 608
# sentences after filtering -> 609
# sentences after filtering -> 610
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# sentences after filtering -> 611
# sentences after filtering -> 612
# sentences after filtering -> 613
# sentences after filtering -> 614
# sentences after filtering -> 615
# eliminada
# eliminada
# sentences after filtering -> 616
# sentences after filtering -> 617
# sentences after filtering -> 618
# sentences after filtering -> 619
# sentences after filtering -> 620
# sentences after filtering -> 621
# sentences after filtering -> 622
# sentences after filtering -> 623
# sentences after filtering -> 624
# sentences after filtering -> 625
# sentences after filtering -> 626
# eliminada
# sentences after filtering -> 627
# sentences after filtering -> 628
# sentences after filtering -> 629
# sentences after filtering -> 630
# sentences after filtering -> 631
# sentences after filtering -> 632
# sentences after filtering -> 633
# sentences after filtering -> 634
# sentences after filtering -> 635
# sentences after filtering -> 636
# sentences after filtering -> 637
# sentences after filtering -> 638
# sentences after filtering -> 639
# sentences after filtering -> 640
# sentences after filtering -> 641
# sentences after filtering -> 642
# sentences after filtering -> 643
# sentences after filtering -> 644
# sentences after filtering -> 645
# sentences after filtering -> 646
# sentences after filtering -> 647
# sentences after filtering -> 648
# sentences after filtering -> 649
# sentences after filtering -> 650
# sentences after filtering -> 651
# sentences after filtering -> 652
# sentences after filtering -> 653
# sentences after filtering -> 654
# sentences after filtering -> 655
# sentences after filtering -> 656
# sentences after filtering -> 657
# sentences after filtering -> 658
# sentences after filtering -> 659
# sentences after filtering -> 660
# sentences after filtering -> 661
# sentences after filtering -> 662
# sentences after filtering -> 663
# sentences after filtering -> 664
# sentences after filtering -> 665
# sentences after filtering -> 666
# sentences after filtering -> 667
# sentences after filtering -> 668
# eliminada
# sentences after filtering -> 669
# sentences after filtering -> 670
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# sentences after filtering -> 671
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# sentences after filtering -> 672
# sentences after filtering -> 673
# sentences after filtering -> 674
# sentences after filtering -> 675
# sentences after filtering -> 676
# sentences after filtering -> 677
# sentences after filtering -> 678
# sentences after filtering -> 679
# sentences after filtering -> 680
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# sentences after filtering -> 681
# sentences after filtering -> 682
# eliminada
# eliminada
# eliminada
# sentences after filtering -> 683
# sentences after filtering -> 684
# sentences after filtering -> 685
# sentences after filtering -> 686
# sentences after filtering -> 687
# sentences after filtering -> 688
# sentences after filtering -> 689
# sentences after filtering -> 690
# sentences after filtering -> 691
# sentences after filtering -> 692
# sentences after filtering -> 693
# sentences after filtering -> 694
# sentences after filtering -> 695
# sentences after filtering -> 696
# sentences after filtering -> 697
# sentences after filtering -> 698
# sentences after filtering -> 699
# sentences after filtering -> 700
# sentences after filtering -> 701
# sentences after filtering -> 702
# sentences after filtering -> 703
# sentences after filtering -> 704
# sentences after filtering -> 705
# sentences after filtering -> 706
# sentences after filtering -> 707
# sentences after filtering -> 708
# sentences after filtering -> 709
# sentences after filtering -> 710
# sentences after filtering -> 711
# sentences after filtering -> 712
# sentences after filtering -> 713
# sentences after filtering -> 714
# sentences after filtering -> 715
# sentences after filtering -> 716
# sentences after filtering -> 717
# sentences after filtering -> 718
# sentences after filtering -> 719
# sentences after filtering -> 720
# sentences after filtering -> 721
# sentences after filtering -> 722
# sentences after filtering -> 723
# sentences after filtering -> 724
# sentences after filtering -> 725
# sentences after filtering -> 726
# sentences after filtering -> 727
# sentences after filtering -> 728
# sentences after filtering -> 729
# sentences after filtering -> 730
# sentences after filtering -> 731
# sentences after filtering -> 732
# sentences after filtering -> 733
# sentences after filtering -> 734
# sentences after filtering -> 735
# sentences after filtering -> 736
# sentences after filtering -> 737
# sentences after filtering -> 738
# sentences after filtering -> 739
# sentences after filtering -> 740
# sentences after filtering -> 741
# sentences after filtering -> 742
# sentences after filtering -> 743
# sentences after filtering -> 744
# sentences after filtering -> 745
# sentences after filtering -> 746
# sentences after filtering -> 747
# sentences after filtering -> 748
# sentences after filtering -> 749
# sentences after filtering -> 750
# sentences after filtering -> 751
# sentences after filtering -> 752
# sentences after filtering -> 753
# sentences after filtering -> 754
# sentences after filtering -> 755
# sentences after filtering -> 756
# sentences after filtering -> 757
# sentences after filtering -> 758
# sentences after filtering -> 759
# sentences after filtering -> 760
# sentences after filtering -> 761
# sentences after filtering -> 762
# sentences after filtering -> 763
# sentences after filtering -> 764
# sentences after filtering -> 765
# sentences after filtering -> 766
# sentences after filtering -> 767
# sentences after filtering -> 768
# sentences after filtering -> 769
# sentences after filtering -> 770
# sentences after filtering -> 771
# sentences after filtering -> 772
# sentences after filtering -> 773
# sentences after filtering -> 774
# sentences after filtering -> 775
# sentences after filtering -> 776
# sentences after filtering -> 777
# sentences after filtering -> 778
# sentences after filtering -> 779
# sentences after filtering -> 780
# sentences after filtering -> 781
# sentences after filtering -> 782
# sentences after filtering -> 783
# sentences after filtering -> 784
# sentences after filtering -> 785
# sentences after filtering -> 786
# sentences after filtering -> 787
# sentences after filtering -> 788
# sentences after filtering -> 789
# sentences after filtering -> 790
# sentences after filtering -> 791
# sentences after filtering -> 792
# sentences after filtering -> 793
# sentences after filtering -> 794
# sentences after filtering -> 795
# sentences after filtering -> 796
# sentences after filtering -> 797
# sentences after filtering -> 798
# sentences after filtering -> 799
# sentences after filtering -> 800
# sentences after filtering -> 801
# sentences after filtering -> 802
# sentences after filtering -> 803
# sentences after filtering -> 804
# sentences after filtering -> 805
# sentences after filtering -> 806
# sentences after filtering -> 807
# sentences after filtering -> 808
# sentences after filtering -> 809
# sentences after filtering -> 810
# sentences after filtering -> 811
# sentences after filtering -> 812
# sentences after filtering -> 813
# sentences after filtering -> 814
# sentences after filtering -> 815
# sentences after filtering -> 816
# sentences after filtering -> 817
# sentences after filtering -> 818
# sentences after filtering -> 819
# sentences after filtering -> 820
# sentences after filtering -> 821
# sentences after filtering -> 822
# sentences after filtering -> 823
# sentences after filtering -> 824
# sentences after filtering -> 825
# sentences after filtering -> 826
# sentences after filtering -> 827
# eliminada
# sentences after filtering -> 828
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# sentences after filtering -> 829
# sentences after filtering -> 830
# sentences after filtering -> 831
# sentences after filtering -> 832
# sentences after filtering -> 833
# sentences after filtering -> 834
# sentences after filtering -> 835
# sentences after filtering -> 836
# sentences after filtering -> 837
# sentences after filtering -> 838
# sentences after filtering -> 839
# sentences after filtering -> 840
# sentences after filtering -> 841
# sentences after filtering -> 842
# sentences after filtering -> 843
# sentences after filtering -> 844
# sentences after filtering -> 845
# sentences after filtering -> 846
# sentences after filtering -> 847
# sentences after filtering -> 848
# sentences after filtering -> 849
# sentences after filtering -> 850
# sentences after filtering -> 851
# sentences after filtering -> 852
# sentences after filtering -> 853
# sentences after filtering -> 854
# sentences after filtering -> 855
# sentences after filtering -> 856
# sentences after filtering -> 857
# sentences after filtering -> 858
# sentences after filtering -> 859
# sentences after filtering -> 860
# sentences after filtering -> 861
# sentences after filtering -> 862
# sentences after filtering -> 863
# sentences after filtering -> 864
# sentences after filtering -> 865
# sentences after filtering -> 866
# eliminada
# sentences after filtering -> 867
# sentences after filtering -> 868
# sentences after filtering -> 869
# sentences after filtering -> 870
# sentences after filtering -> 871
# sentences after filtering -> 872
# eliminada
# sentences after filtering -> 873
# sentences after filtering -> 874
# sentences after filtering -> 875
# sentences after filtering -> 876
# sentences after filtering -> 877
# sentences after filtering -> 878
# sentences after filtering -> 879
# sentences after filtering -> 880
# sentences after filtering -> 881
# sentences after filtering -> 882
# sentences after filtering -> 883
# sentences after filtering -> 884
# sentences after filtering -> 885
# sentences after filtering -> 886
# sentences after filtering -> 887
# sentences after filtering -> 888
# sentences after filtering -> 889
# eliminada
# sentences after filtering -> 890
# sentences after filtering -> 891
# sentences after filtering -> 892
# sentences after filtering -> 893
# sentences after filtering -> 894
# sentences after filtering -> 895
# sentences after filtering -> 896
# sentences after filtering -> 897
# sentences after filtering -> 898
# eliminada
# eliminada
# sentences after filtering -> 899
# sentences after filtering -> 900
# sentences after filtering -> 901
# sentences after filtering -> 902
# sentences after filtering -> 903
# sentences after filtering -> 904
# sentences after filtering -> 905
# sentences after filtering -> 906
# sentences after filtering -> 907
# sentences after filtering -> 908
# sentences after filtering -> 909
# sentences after filtering -> 910
# sentences after filtering -> 911
# eliminada
# eliminada
# eliminada
# sentences after filtering -> 912
# sentences after filtering -> 913
# sentences after filtering -> 914
# sentences after filtering -> 915
# sentences after filtering -> 916
# sentences after filtering -> 917
# sentences after filtering -> 918
# sentences after filtering -> 919
# sentences after filtering -> 920
# sentences after filtering -> 921
# sentences after filtering -> 922
# sentences after filtering -> 923
# sentences after filtering -> 924
# sentences after filtering -> 925
# sentences after filtering -> 926
# sentences after filtering -> 927
# sentences after filtering -> 928
# sentences after filtering -> 929
# sentences after filtering -> 930
# sentences after filtering -> 931
# sentences after filtering -> 932
# sentences after filtering -> 933
# sentences after filtering -> 934
# sentences after filtering -> 935
# sentences after filtering -> 936
# sentences after filtering -> 937
# sentences after filtering -> 938
# sentences after filtering -> 939
# sentences after filtering -> 940
# sentences after filtering -> 941
# sentences after filtering -> 942
# sentences after filtering -> 943
# sentences after filtering -> 944
# sentences after filtering -> 945
# sentences after filtering -> 946
# sentences after filtering -> 947
# sentences after filtering -> 948
# sentences after filtering -> 949
# sentences after filtering -> 950
# sentences after filtering -> 951
# sentences after filtering -> 952
# sentences after filtering -> 953
# sentences after filtering -> 954
# sentences after filtering -> 955
# sentences after filtering -> 956
# sentences after filtering -> 957
# sentences after filtering -> 958
# sentences after filtering -> 959
# sentences after filtering -> 960
# sentences after filtering -> 961
# sentences after filtering -> 962
# sentences after filtering -> 963
# sentences after filtering -> 964
# sentences after filtering -> 965
# sentences after filtering -> 966
# sentences after filtering -> 967
# sentences after filtering -> 968
# sentences after filtering -> 969
# sentences after filtering -> 970
# sentences after filtering -> 971
# sentences after filtering -> 972
# sentences after filtering -> 973
# sentences after filtering -> 974
# sentences after filtering -> 975
# sentences after filtering -> 976
# sentences after filtering -> 977
# sentences after filtering -> 978
# sentences after filtering -> 979
# sentences after filtering -> 980
# sentences after filtering -> 981
# sentences after filtering -> 982
# sentences after filtering -> 983
# sentences after filtering -> 984
# sentences after filtering -> 985
# sentences after filtering -> 986
# sentences after filtering -> 987
# sentences after filtering -> 988
# sentences after filtering -> 989
# sentences after filtering -> 990
# sentences after filtering -> 991
# sentences after filtering -> 992
# sentences after filtering -> 993
# sentences after filtering -> 994
# sentences after filtering -> 995
# sentences after filtering -> 996
# sentences after filtering -> 997
# sentences after filtering -> 998
# sentences after filtering -> 999
# sentences after filtering -> 1000
# sentences after filtering -> 1001
# sentences after filtering -> 1002
# sentences after filtering -> 1003
# sentences after filtering -> 1004
# sentences after filtering -> 1005
# sentences after filtering -> 1006
# sentences after filtering -> 1007
# sentences after filtering -> 1008
# sentences after filtering -> 1009
# sentences after filtering -> 1010
# sentences after filtering -> 1011
# sentences after filtering -> 1012
# sentences after filtering -> 1013
# sentences after filtering -> 1014
# sentences after filtering -> 1015
# sentences after filtering -> 1016
# sentences after filtering -> 1017
# sentences after filtering -> 1018
# sentences after filtering -> 1019
# sentences after filtering -> 1020
# sentences after filtering -> 1021
# sentences after filtering -> 1022
# eliminada
# sentences after filtering -> 1023
# sentences after filtering -> 1024
# sentences after filtering -> 1025
# sentences after filtering -> 1026
# sentences after filtering -> 1027
# sentences after filtering -> 1028
# sentences after filtering -> 1029
# sentences after filtering -> 1030
# sentences after filtering -> 1031
# sentences after filtering -> 1032
# sentences after filtering -> 1033
# sentences after filtering -> 1034
# sentences after filtering -> 1035
# sentences after filtering -> 1036
# sentences after filtering -> 1037
# sentences after filtering -> 1038
# sentences after filtering -> 1039
# sentences after filtering -> 1040
# sentences after filtering -> 1041
# sentences after filtering -> 1042
# sentences after filtering -> 1043
# sentences after filtering -> 1044
# sentences after filtering -> 1045
# sentences after filtering -> 1046
# sentences after filtering -> 1047
# sentences after filtering -> 1048
# sentences after filtering -> 1049
# sentences after filtering -> 1050
# sentences after filtering -> 1051
# sentences after filtering -> 1052
# sentences after filtering -> 1053
# sentences after filtering -> 1054
# sentences after filtering -> 1055
# sentences after filtering -> 1056
# sentences after filtering -> 1057
# sentences after filtering -> 1058
# sentences after filtering -> 1059
# sentences after filtering -> 1060
# sentences after filtering -> 1061
# sentences after filtering -> 1062
# sentences after filtering -> 1063
# sentences after filtering -> 1064
# sentences after filtering -> 1065
# sentences after filtering -> 1066
# sentences after filtering -> 1067
# eliminada
# sentences after filtering -> 1068
# sentences after filtering -> 1069
# sentences after filtering -> 1070
# sentences after filtering -> 1071
# sentences after filtering -> 1072
# sentences after filtering -> 1073
# sentences after filtering -> 1074
# sentences after filtering -> 1075
# sentences after filtering -> 1076
# sentences after filtering -> 1077
# sentences after filtering -> 1078
# sentences after filtering -> 1079
# sentences after filtering -> 1080
# sentences after filtering -> 1081
# sentences after filtering -> 1082
# sentences after filtering -> 1083
# sentences after filtering -> 1084
# sentences after filtering -> 1085
# sentences after filtering -> 1086
# sentences after filtering -> 1087
# sentences after filtering -> 1088
# sentences after filtering -> 1089
# sentences after filtering -> 1090
# sentences after filtering -> 1091
# sentences after filtering -> 1092
# sentences after filtering -> 1093
# sentences after filtering -> 1094
# sentences after filtering -> 1095
# sentences after filtering -> 1096
# sentences after filtering -> 1097
# sentences after filtering -> 1098
# sentences after filtering -> 1099
# sentences after filtering -> 1100
# sentences after filtering -> 1101
# sentences after filtering -> 1102
# eliminada
# sentences after filtering -> 1103
# sentences after filtering -> 1104
# sentences after filtering -> 1105
# sentences after filtering -> 1106
# sentences after filtering -> 1107
# sentences after filtering -> 1108
# sentences after filtering -> 1109
# sentences after filtering -> 1110
# sentences after filtering -> 1111
# sentences after filtering -> 1112
# sentences after filtering -> 1113
# eliminada
# sentences after filtering -> 1114
# sentences after filtering -> 1115
# sentences after filtering -> 1116
# sentences after filtering -> 1117
# sentences after filtering -> 1118
# sentences after filtering -> 1119
# sentences after filtering -> 1120
# sentences after filtering -> 1121
# sentences after filtering -> 1122
# sentences after filtering -> 1123
# sentences after filtering -> 1124
# sentences after filtering -> 1125
# sentences after filtering -> 1126
# sentences after filtering -> 1127
# sentences after filtering -> 1128
# sentences after filtering -> 1129
# sentences after filtering -> 1130
# sentences after filtering -> 1131
# sentences after filtering -> 1132
# sentences after filtering -> 1133
# sentences after filtering -> 1134
# sentences after filtering -> 1135
# sentences after filtering -> 1136
# sentences after filtering -> 1137
# sentences after filtering -> 1138
# sentences after filtering -> 1139
# sentences after filtering -> 1140
# sentences after filtering -> 1141
# sentences after filtering -> 1142
# sentences after filtering -> 1143
# sentences after filtering -> 1144
# sentences after filtering -> 1145
# sentences after filtering -> 1146
# sentences after filtering -> 1147
# sentences after filtering -> 1148
# sentences after filtering -> 1149
# sentences after filtering -> 1150
# sentences after filtering -> 1151
# sentences after filtering -> 1152
# sentences after filtering -> 1153
# sentences after filtering -> 1154
# sentences after filtering -> 1155
# sentences after filtering -> 1156
# sentences after filtering -> 1157
# sentences after filtering -> 1158
# sentences after filtering -> 1159
# sentences after filtering -> 1160
# sentences after filtering -> 1161
# sentences after filtering -> 1162
# sentences after filtering -> 1163
# sentences after filtering -> 1164
# sentences after filtering -> 1165
# sentences after filtering -> 1166
# sentences after filtering -> 1167
# sentences after filtering -> 1168
# sentences after filtering -> 1169
# sentences after filtering -> 1170
# sentences after filtering -> 1171
# sentences after filtering -> 1172
# sentences after filtering -> 1173
# sentences after filtering -> 1174
# sentences after filtering -> 1175
# sentences after filtering -> 1176
# sentences after filtering -> 1177
# sentences after filtering -> 1178
# sentences after filtering -> 1179
# sentences after filtering -> 1180
# sentences after filtering -> 1181
# eliminada
# sentences after filtering -> 1182
# sentences after filtering -> 1183
# sentences after filtering -> 1184
# sentences after filtering -> 1185
# sentences after filtering -> 1186
# sentences after filtering -> 1187
# sentences after filtering -> 1188
# sentences after filtering -> 1189
# sentences after filtering -> 1190
# eliminada
# sentences after filtering -> 1191
# sentences after filtering -> 1192
# sentences after filtering -> 1193
# sentences after filtering -> 1194
# sentences after filtering -> 1195
# sentences after filtering -> 1196
# sentences after filtering -> 1197
# sentences after filtering -> 1198
# sentences after filtering -> 1199
# sentences after filtering -> 1200
# sentences after filtering -> 1201
# sentences after filtering -> 1202
# sentences after filtering -> 1203
# sentences after filtering -> 1204
# sentences after filtering -> 1205
# sentences after filtering -> 1206
# sentences after filtering -> 1207
# sentences after filtering -> 1208
# sentences after filtering -> 1209
# sentences after filtering -> 1210
# sentences after filtering -> 1211
# sentences after filtering -> 1212
# sentences after filtering -> 1213
# sentences after filtering -> 1214
# sentences after filtering -> 1215
# sentences after filtering -> 1216
# sentences after filtering -> 1217
# sentences after filtering -> 1218
# sentences after filtering -> 1219
# eliminada
# eliminada
# eliminada
# sentences after filtering -> 1220
# sentences after filtering -> 1221
# sentences after filtering -> 1222
# sentences after filtering -> 1223
# sentences after filtering -> 1224
# sentences after filtering -> 1225
# sentences after filtering -> 1226
# sentences after filtering -> 1227
# sentences after filtering -> 1228
# sentences after filtering -> 1229
# sentences after filtering -> 1230
# sentences after filtering -> 1231
# sentences after filtering -> 1232
# sentences after filtering -> 1233
# sentences after filtering -> 1234
# sentences after filtering -> 1235
# sentences after filtering -> 1236
# sentences after filtering -> 1237
# sentences after filtering -> 1238
# sentences after filtering -> 1239
# sentences after filtering -> 1240
# sentences after filtering -> 1241
# sentences after filtering -> 1242
# sentences after filtering -> 1243
# sentences after filtering -> 1244
# sentences after filtering -> 1245
# sentences after filtering -> 1246
# sentences after filtering -> 1247
# sentences after filtering -> 1248
# sentences after filtering -> 1249
# sentences after filtering -> 1250
# sentences after filtering -> 1251
# sentences after filtering -> 1252
# sentences after filtering -> 1253
# sentences after filtering -> 1254
# sentences after filtering -> 1255
# sentences after filtering -> 1256
# sentences after filtering -> 1257
# sentences after filtering -> 1258
# sentences after filtering -> 1259
# sentences after filtering -> 1260
# sentences after filtering -> 1261
# sentences after filtering -> 1262
# sentences after filtering -> 1263
# sentences after filtering -> 1264
# sentences after filtering -> 1265
# sentences after filtering -> 1266
# sentences after filtering -> 1267
# sentences after filtering -> 1268
# sentences after filtering -> 1269
# sentences after filtering -> 1270
# sentences after filtering -> 1271
# sentences after filtering -> 1272
# sentences after filtering -> 1273
# sentences after filtering -> 1274
# sentences after filtering -> 1275
# sentences after filtering -> 1276
# sentences after filtering -> 1277
# sentences after filtering -> 1278
# sentences after filtering -> 1279
# sentences after filtering -> 1280
# sentences after filtering -> 1281
# sentences after filtering -> 1282
# sentences after filtering -> 1283
# sentences after filtering -> 1284
# sentences after filtering -> 1285
# sentences after filtering -> 1286
# sentences after filtering -> 1287
# sentences after filtering -> 1288
# sentences after filtering -> 1289
# sentences after filtering -> 1290
# sentences after filtering -> 1291
# sentences after filtering -> 1292
# sentences after filtering -> 1293
# sentences after filtering -> 1294
# sentences after filtering -> 1295
# sentences after filtering -> 1296
# sentences after filtering -> 1297
# sentences after filtering -> 1298
# sentences after filtering -> 1299
# sentences after filtering -> 1300
# sentences after filtering -> 1301
# sentences after filtering -> 1302
# sentences after filtering -> 1303
# sentences after filtering -> 1304
# sentences after filtering -> 1305
# sentences after filtering -> 1306
# sentences after filtering -> 1307
# sentences after filtering -> 1308
# eliminada
# sentences after filtering -> 1309
# sentences after filtering -> 1310
# sentences after filtering -> 1311
# sentences after filtering -> 1312
# sentences after filtering -> 1313
# sentences after filtering -> 1314
# sentences after filtering -> 1315
# sentences after filtering -> 1316
# sentences after filtering -> 1317
# sentences after filtering -> 1318
# sentences after filtering -> 1319
# sentences after filtering -> 1320
# sentences after filtering -> 1321
# sentences after filtering -> 1322
# sentences after filtering -> 1323
# sentences after filtering -> 1324
# sentences after filtering -> 1325
# sentences after filtering -> 1326
# sentences after filtering -> 1327
# sentences after filtering -> 1328
# sentences after filtering -> 1329
# sentences after filtering -> 1330
# sentences after filtering -> 1331
# sentences after filtering -> 1332
# sentences after filtering -> 1333
# sentences after filtering -> 1334
# sentences after filtering -> 1335
# sentences after filtering -> 1336
# sentences after filtering -> 1337
# sentences after filtering -> 1338
# sentences after filtering -> 1339
# sentences after filtering -> 1340
# sentences after filtering -> 1341
# sentences after filtering -> 1342
# sentences after filtering -> 1343
# sentences after filtering -> 1344
# sentences after filtering -> 1345
# sentences after filtering -> 1346
# sentences after filtering -> 1347
# sentences after filtering -> 1348
# sentences after filtering -> 1349
# sentences after filtering -> 1350
# sentences after filtering -> 1351
# sentences after filtering -> 1352
# sentences after filtering -> 1353
# sentences after filtering -> 1354
# sentences after filtering -> 1355
# sentences after filtering -> 1356
# sentences after filtering -> 1357
# sentences after filtering -> 1358
# sentences after filtering -> 1359
# sentences after filtering -> 1360
# sentences after filtering -> 1361
# sentences after filtering -> 1362
# sentences after filtering -> 1363
# sentences after filtering -> 1364
# sentences after filtering -> 1365
# sentences after filtering -> 1366
# sentences after filtering -> 1367
# sentences after filtering -> 1368
# sentences after filtering -> 1369
# sentences after filtering -> 1370
# sentences after filtering -> 1371
# sentences after filtering -> 1372
# sentences after filtering -> 1373
# sentences after filtering -> 1374
# sentences after filtering -> 1375
# sentences after filtering -> 1376
# sentences after filtering -> 1377
# sentences after filtering -> 1378
# sentences after filtering -> 1379
# sentences after filtering -> 1380
# sentences after filtering -> 1381
# sentences after filtering -> 1382
# sentences after filtering -> 1383
# sentences after filtering -> 1384
# sentences after filtering -> 1385
# sentences after filtering -> 1386
# sentences after filtering -> 1387
# sentences after filtering -> 1388
# sentences after filtering -> 1389
# sentences after filtering -> 1390
# sentences after filtering -> 1391
# sentences after filtering -> 1392
# sentences after filtering -> 1393
# sentences after filtering -> 1394
# sentences after filtering -> 1395
# sentences after filtering -> 1396
# sentences after filtering -> 1397
# sentences after filtering -> 1398
# sentences after filtering -> 1399
# sentences after filtering -> 1400
# sentences after filtering -> 1401
# sentences after filtering -> 1402
# sentences after filtering -> 1403
# sentences after filtering -> 1404
# sentences after filtering -> 1405
# sentences after filtering -> 1406
# sentences after filtering -> 1407
# sentences after filtering -> 1408
# sentences after filtering -> 1409
# sentences after filtering -> 1410
# sentences after filtering -> 1411
# sentences after filtering -> 1412
# sentences after filtering -> 1413
# ...
# sentences after filtering -> 4135
# sentences after filtering -> 4136
# sentences after filtering -> 4137
# sentences after filtering -> 4138
# sentences after filtering -> 4139
# sentences after filtering -> 4140
# sentences after filtering -> 4141
# sentences after filtering -> 4142
# sentences after filtering -> 4143
# sentences after filtering -> 4144
# sentences after filtering -> 4145
# sentences after filtering -> 4146
# sentences after filtering -> 4147
# sentences after filtering -> 4148
# sentences after filtering -> 4149
# sentences after filtering -> 4150
# sentences after filtering -> 4151
# sentences after filtering -> 4152
# sentences after filtering -> 4153
# sentences after filtering -> 4154
# sentences after filtering -> 4155
# sentences after filtering -> 4156
# sentences after filtering -> 4157
# sentences after filtering -> 4158
# sentences after filtering -> 4159
# sentences after filtering -> 4160
# sentences after filtering -> 4161
# sentences after filtering -> 4162
# sentences after filtering -> 4163
# sentences after filtering -> 4164
# sentences after filtering -> 4165
# sentences after filtering -> 4166
# sentences after filtering -> 4167
# sentences after filtering -> 4168
# sentences after filtering -> 4169
# sentences after filtering -> 4170
# sentences after filtering -> 4171
# sentences after filtering -> 4172
# sentences after filtering -> 4173
# sentences after filtering -> 4174
# sentences after filtering -> 4175
# sentences after filtering -> 4176
# eliminada
# eliminada
# sentences after filtering -> 4177
# sentences after filtering -> 4178
# sentences after filtering -> 4179
# sentences after filtering -> 4180
# sentences after filtering -> 4181
# eliminada
# eliminada
# sentences after filtering -> 4182
# sentences after filtering -> 4183
# sentences after filtering -> 4184
# sentences after filtering -> 4185
# sentences after filtering -> 4186
# sentences after filtering -> 4187
# sentences after filtering -> 4188
# sentences after filtering -> 4189
# sentences after filtering -> 4190
# sentences after filtering -> 4191
# sentences after filtering -> 4192
# eliminada
# eliminada
# sentences after filtering -> 4193
# eliminada
# eliminada
# eliminada
# sentences after filtering -> 4194
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# sentences after filtering -> 4195
# sentences after filtering -> 4196
# sentences after filtering -> 4197
# sentences after filtering -> 4198
# sentences after filtering -> 4199
# sentences after filtering -> 4200
# sentences after filtering -> 4201
# sentences after filtering -> 4202
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# sentences after filtering -> 4203
# sentences after filtering -> 4204
# sentences after filtering -> 4205
# sentences after filtering -> 4206
# sentences after filtering -> 4207
# sentences after filtering -> 4208
# sentences after filtering -> 4209
# sentences after filtering -> 4210
# sentences after filtering -> 4211
# sentences after filtering -> 4212
# sentences after filtering -> 4213
# sentences after filtering -> 4214
# sentences after filtering -> 4215
# sentences after filtering -> 4216
# sentences after filtering -> 4217
# sentences after filtering -> 4218
# sentences after filtering -> 4219
# sentences after filtering -> 4220
# eliminada
# eliminada
# sentences after filtering -> 4221
# sentences after filtering -> 4222
# sentences after filtering -> 4223
# sentences after filtering -> 4224
# sentences after filtering -> 4225
# sentences after filtering -> 4226
# sentences after filtering -> 4227
# sentences after filtering -> 4228
# sentences after filtering -> 4229
# sentences after filtering -> 4230
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# sentences after filtering -> 4231
# sentences after filtering -> 4232
# sentences after filtering -> 4233
# sentences after filtering -> 4234
# sentences after filtering -> 4235
# sentences after filtering -> 4236
# eliminada
# sentences after filtering -> 4237
# sentences after filtering -> 4238
# eliminada
# sentences after filtering -> 4239
# sentences after filtering -> 4240
# sentences after filtering -> 4241
# sentences after filtering -> 4242
# sentences after filtering -> 4243
# sentences after filtering -> 4244
# sentences after filtering -> 4245
# sentences after filtering -> 4246
# sentences after filtering -> 4247
# sentences after filtering -> 4248
# sentences after filtering -> 4249
# sentences after filtering -> 4250
# sentences after filtering -> 4251
# sentences after filtering -> 4252
# sentences after filtering -> 4253
# sentences after filtering -> 4254
# sentences after filtering -> 4255
# sentences after filtering -> 4256
# sentences after filtering -> 4257
# sentences after filtering -> 4258
# sentences after filtering -> 4259
# sentences after filtering -> 4260
# sentences after filtering -> 4261
# sentences after filtering -> 4262
# sentences after filtering -> 4263
# sentences after filtering -> 4264
# sentences after filtering -> 4265
# sentences after filtering -> 4266
# sentences after filtering -> 4267
# sentences after filtering -> 4268
# sentences after filtering -> 4269
# sentences after filtering -> 4270
# sentences after filtering -> 4271
# sentences after filtering -> 4272
# sentences after filtering -> 4273
# sentences after filtering -> 4274
# sentences after filtering -> 4275
# sentences after filtering -> 4276
# eliminada
# eliminada
# sentences after filtering -> 4277
# eliminada
# sentences after filtering -> 4278
# sentences after filtering -> 4279
# sentences after filtering -> 4280
# sentences after filtering -> 4281
# sentences after filtering -> 4282
# sentences after filtering -> 4283
# sentences after filtering -> 4284
# sentences after filtering -> 4285
# sentences after filtering -> 4286
# sentences after filtering -> 4287
# sentences after filtering -> 4288
# sentences after filtering -> 4289
# sentences after filtering -> 4290
# sentences after filtering -> 4291
# sentences after filtering -> 4292
# sentences after filtering -> 4293
# sentences after filtering -> 4294
# sentences after filtering -> 4295
# sentences after filtering -> 4296
# sentences after filtering -> 4297
# sentences after filtering -> 4298
# sentences after filtering -> 4299
# sentences after filtering -> 4300
# sentences after filtering -> 4301
# sentences after filtering -> 4302
# sentences after filtering -> 4303
# sentences after filtering -> 4304
# sentences after filtering -> 4305
# sentences after filtering -> 4306
# sentences after filtering -> 4307
# sentences after filtering -> 4308
# sentences after filtering -> 4309
# sentences after filtering -> 4310
# sentences after filtering -> 4311
# sentences after filtering -> 4312
# sentences after filtering -> 4313
# sentences after filtering -> 4314
# sentences after filtering -> 4315
# sentences after filtering -> 4316
# sentences after filtering -> 4317
# sentences after filtering -> 4318
# sentences after filtering -> 4319
# sentences after filtering -> 4320
# sentences after filtering -> 4321
# sentences after filtering -> 4322
# sentences after filtering -> 4323
# sentences after filtering -> 4324
# sentences after filtering -> 4325
# sentences after filtering -> 4326
# sentences after filtering -> 4327
# sentences after filtering -> 4328
# sentences after filtering -> 4329
# sentences after filtering -> 4330
# sentences after filtering -> 4331
# sentences after filtering -> 4332
# sentences after filtering -> 4333
# sentences after filtering -> 4334
# sentences after filtering -> 4335
# sentences after filtering -> 4336
# sentences after filtering -> 4337
# sentences after filtering -> 4338
# sentences after filtering -> 4339
# sentences after filtering -> 4340
# sentences after filtering -> 4341
# sentences after filtering -> 4342
# sentences after filtering -> 4343
# sentences after filtering -> 4344
# sentences after filtering -> 4345
# sentences after filtering -> 4346
# sentences after filtering -> 4347
# sentences after filtering -> 4348
# sentences after filtering -> 4349
# sentences after filtering -> 4350
# sentences after filtering -> 4351
# sentences after filtering -> 4352
# sentences after filtering -> 4353
# sentences after filtering -> 4354
# sentences after filtering -> 4355
# eliminada
# eliminada
# eliminada
# sentences after filtering -> 4356
# sentences after filtering -> 4357
# sentences after filtering -> 4358
# sentences after filtering -> 4359
# sentences after filtering -> 4360
# sentences after filtering -> 4361
# sentences after filtering -> 4362
# sentences after filtering -> 4363
# eliminada
# eliminada
# eliminada
# eliminada
# sentences after filtering -> 4364
# eliminada
# eliminada
# sentences after filtering -> 4365
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# sentences after filtering -> 4366
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# sentences after filtering -> 4367
# sentences after filtering -> 4368
# sentences after filtering -> 4369
# sentences after filtering -> 4370
# sentences after filtering -> 4371
# sentences after filtering -> 4372
# sentences after filtering -> 4373
# sentences after filtering -> 4374
# sentences after filtering -> 4375
# sentences after filtering -> 4376
# sentences after filtering -> 4377
# sentences after filtering -> 4378
# sentences after filtering -> 4379
# sentences after filtering -> 4380
# sentences after filtering -> 4381
# sentences after filtering -> 4382
# sentences after filtering -> 4383
# sentences after filtering -> 4384
# sentences after filtering -> 4385
# sentences after filtering -> 4386
# sentences after filtering -> 4387
# sentences after filtering -> 4388
# sentences after filtering -> 4389
# sentences after filtering -> 4390
# sentences after filtering -> 4391
# sentences after filtering -> 4392
# sentences after filtering -> 4393
# sentences after filtering -> 4394
# start_char com problema
# eliminada
# eliminada
# sentences after filtering -> 4395
# sentences after filtering -> 4396
# sentences after filtering -> 4397
# sentences after filtering -> 4398
# sentences after filtering -> 4399
# sentences after filtering -> 4400
# sentences after filtering -> 4401
# sentences after filtering -> 4402
# sentences after filtering -> 4403
# sentences after filtering -> 4404
# sentences after filtering -> 4405
# sentences after filtering -> 4406
# sentences after filtering -> 4407
# sentences after filtering -> 4408
# sentences after filtering -> 4409
# sentences after filtering -> 4410
# sentences after filtering -> 4411
# sentences after filtering -> 4412
# sentences after filtering -> 4413
# sentences after filtering -> 4414
# sentences after filtering -> 4415
# sentences after filtering -> 4416
# sentences after filtering -> 4417
# sentences after filtering -> 4418
# sentences after filtering -> 4419
# sentences after filtering -> 4420
# sentences after filtering -> 4421
# sentences after filtering -> 4422
# sentences after filtering -> 4423
# sentences after filtering -> 4424
# sentences after filtering -> 4425
# sentences after filtering -> 4426
# sentences after filtering -> 4427
# sentences after filtering -> 4428
# sentences after filtering -> 4429
# sentences after filtering -> 4430
# sentences after filtering -> 4431
# sentences after filtering -> 4432
# sentences after filtering -> 4433
# sentences after filtering -> 4434
# eliminada
# eliminada
# sentences after filtering -> 4435
# sentences after filtering -> 4436
# sentences after filtering -> 4437
# sentences after filtering -> 4438
# sentences after filtering -> 4439
# sentences after filtering -> 4440
# sentences after filtering -> 4441
# sentences after filtering -> 4442
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# sentences after filtering -> 4443
# sentences after filtering -> 4444
# sentences after filtering -> 4445
# eliminada
# eliminada
# sentences after filtering -> 4446
# sentences after filtering -> 4447
# sentences after filtering -> 4448
# sentences after filtering -> 4449
# sentences after filtering -> 4450
# sentences after filtering -> 4451
# sentences after filtering -> 4452
# sentences after filtering -> 4453
# sentences after filtering -> 4454
# sentences after filtering -> 4455
# sentences after filtering -> 4456
# sentences after filtering -> 4457
# sentences after filtering -> 4458
# sentences after filtering -> 4459
# sentences after filtering -> 4460
# sentences after filtering -> 4461
# sentences after filtering -> 4462
# sentences after filtering -> 4463
# sentences after filtering -> 4464
# sentences after filtering -> 4465
# sentences after filtering -> 4466
# sentences after filtering -> 4467
# sentences after filtering -> 4468
# sentences after filtering -> 4469
# sentences after filtering -> 4470
# sentences after filtering -> 4471
# sentences after filtering -> 4472
# sentences after filtering -> 4473
# sentences after filtering -> 4474
# sentences after filtering -> 4475
# sentences after filtering -> 4476
# sentences after filtering -> 4477
# sentences after filtering -> 4478
# sentences after filtering -> 4479
# sentences after filtering -> 4480
# sentences after filtering -> 4481
# sentences after filtering -> 4482
# sentences after filtering -> 4483
# sentences after filtering -> 4484
# sentences after filtering -> 4485
# sentences after filtering -> 4486
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# eliminada
# sentences after filtering -> 4487
# sentences after filtering -> 4488
# eliminada
# eliminada
# sentences after filtering -> 4489
# sentences after filtering -> 4490
# sentences after filtering -> 4491
# sentences after filtering -> 4492
# sentences after filtering -> 4493
# sentences after filtering -> 4494
# sentences after filtering -> 4495
# sentences after filtering -> 4496
# sentences after filtering -> 4497
# sentences after filtering -> 4498
# sentences after filtering -> 4499
# sentences after filtering -> 4500
# sentences after filtering -> 4501
# sentences after filtering -> 4502
# sentences after filtering -> 4503
# sentences after filtering -> 4504
# sentences after filtering -> 4505
# sentences after filtering -> 4506
# sentences after filtering -> 4507
# sentences after filtering -> 4508
# sentences after filtering -> 4509
# sentences after filtering -> 4510
# sentences after filtering -> 4511
# sentences after filtering -> 4512
# sentences after filtering -> 4513
# sentences after filtering -> 4514
# sentences after filtering -> 4515
# eliminada
# eliminada
# sentences after filtering -> 4516
# sentences after filtering -> 4517
# sentences after filtering -> 4518
# sentences after filtering -> 4519
# eliminada
# sentences after filtering -> 4520
# sentences after filtering -> 4521
# sentences after filtering -> 4522
# sentences after filtering -> 4523
# sentences after filtering -> 4524
# sentences after filtering -> 4525
# sentences after filtering -> 4526
# sentences after filtering -> 4527
# sentences after filtering -> 4528
# sentences after filtering -> 4529
# sentences after filtering -> 4530
# sentences after filtering -> 4531
# sentences after filtering -> 4532
# sentences after filtering -> 4533
# sentences after filtering -> 4534
# sentences after filtering -> 4535
# sentences after filtering -> 4536
# sentences after filtering -> 4537
# sentences after filtering -> 4538
# sentences after filtering -> 4539
# sentences after filtering -> 4540
# sentences after filtering -> 4541
# sentences after filtering -> 4542
# ------------
# lista de diferentes tipos de entidades pós filtragem
# ['B=BACIA', 'B=CAMPO', 'B=ESTRUTURA_FÍSICA', 'B=FLUIDO', 'B=FLUIDODATERRA_i', 'B=FLUIDODATERRA_o', 'B=NÃOCONSOLID', 'B=POÇO', 'B=POÇO_Q', 'B=POÇO_R', 'B=POÇO_T', 'B=ROCHA', 'B=TEXTURA', 'B=TIPO_POROSIDADE', 'B=UNIDADE_CRONO', 'B=UNIDADE_LITO']
# ------------
# quantidades de diferentes tipos de entidades pós filtragem
# [2990, 582, 1480, 102, 964, 155, 778, 914, 9, 3, 33, 2192, 37, 19, 2427, 1260]
# ------------
# Total de URIs pós filtragem -> 13945
