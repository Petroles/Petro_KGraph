# %%
# Configurando Proxy

import os
from getpass import getpass

chave  = os.getenv('USER')
senha  = getpass('Senha: ')

os.environ['HTTP_PROXY']  = f'http://{chave}:{senha}@inet-sys.petrobras.com.br:804'
os.environ['HTTPS_PROXY'] = f'http://{chave}:{senha}@inet-sys.petrobras.com.br:804'
os.environ['NO_PROXY']    = '127.0.0.1, localhost, petrobras.com.br, petrobras.biz'
# Out:
# Senha:  ··········

# %%
import numpy as np
import random
from datetime import datetime

import tensorflow as tf
import tensorflow_hub as hub
import tensorflow_text as text
from keras.layers import dot
from scipy.spatial import distance

import gensim
import pandas as pd

from sklearn.cluster import DBSCAN
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt, mpld3
# %matplotlib inline
mpld3.enable_notebook()

# %% [markdown]
# ### Carregando dataset
#
#   Treino e Validação será feito no dataset Triplet, já o teste será feito no dataset de teste do PetroNER adaptado com as marcações de entidades e classes.

# %%
#Treino
URI_anchor_treino =  np.load('../../Corpora/PetroNER - Clustering/URI_anchor_treino.npy')
URIvec_anchor_treino =  np.load('../../Corpora/PetroNER - Clustering/URIvec_anchor_treino.npy')
dataset_anchor_treino = np.load('../../Corpora/PetroNER - Clustering/anchor_treino.npy')
dataset_positive_treino = np.load('../../Corpora/PetroNER - Clustering/positive_treino.npy')
dataset_negative_treino = np.load('../../Corpora/PetroNER - Clustering/negative_treino.npy')

#Validação
URI_anchor_valid =  np.load('../../Corpora/PetroNER - Clustering/URI_anchor_valid.npy')
URIvec_anchor_valid =  np.load('../../Corpora/PetroNER - Clustering/URIvec_anchor_valid.npy')
dataset_anchor_valid = np.load('../../Corpora/PetroNER - Clustering/anchor_valid.npy')
dataset_positive_valid = np.load('../../Corpora/PetroNER - Clustering/positive_valid.npy')
dataset_negative_valid = np.load('../../Corpora/PetroNER - Clustering/negative_valid.npy')

#Teste
teste_text = np.load('../../Corpora/PetroNER-LinkedEntity/teste - sentences.npy')
teste_entities = np.load('../../Corpora/PetroNER-LinkedEntity/teste - entities.npy')
teste_classes_NER = np.load('../../Corpora/PetroNER-LinkedEntity/teste - classes.npy')
teste_ENT_URI = np.load('../../Corpora/PetroNER-LinkedEntity/teste - URI.npy', allow_pickle=True).astype(str)

# %%
print('Treino (triplet): ', len(dataset_anchor_treino))
print('Validação (triplet): ', len(dataset_anchor_valid))
print('Teste (PetroNER): ', len(teste_text))
# Out:
# Treino (triplet):  12388
# Validação (triplet):  3264
# Teste (PetroNER):  3199

# %%
n = 51

print(dataset_anchor_treino[n])
print(dataset_positive_treino[n])
print(dataset_negative_treino[n])
print(URI_anchor_treino[n])
print(URIvec_anchor_treino[n])
# Out:
# [UNIDADE_LITO] Missão Velha | Preliminary constraints on paleotemperature and landscape evolution in and around Araripe Basin, northeastern Brazil, using apatite fission track analysis introdução( ii) uma seqüência pré-rifte de idade jurássica( formações Brejo Santo e [E] Missão Velha [/E]);( iii) uma seqüência rifte de idade neocomiana( Formação Abaiara, composta por arenitos, folhelhos e argilas carbonáticas depositados por sistemas flúvio-lacustres); e um soerguimento tectônico regional( Ponte e Ponte Filho, 1996)..
# [UNIDADE_LITO] Missão Velha | Essa área, aparentemente, manteve-se positiva e submetida a erosão até o Jurássico Superior, quando se formou a“ Depressão Afro-brasileira”( fig. 4), uma calha rasa e alongada onde se depositaram os sedimentos continentais das formações Aliança e Sergi, no Recôncavo, e Serraria em Alagoas/ Sergipe, [E] Missão Velha [/E] do Araripe, e suas correlatas M’ Vone e N’Dombo, do Gabão, na África..
# [BACIA] Bacia de Campos | LOBO, A. P.; FERRADAES, J. O. Reconhecimento preliminar do talude e sopé continentais da [E] Bacia de Campos [/E]..
# #formacao_053
# [ 0.55701476  0.23191205  0.28598157 -1.31507146 -0.46808451  0.27948532
#   0.52606016 -0.43560311 -1.27100587  0.27978176  0.04964242 -0.29406643
#   0.18493919  0.27208787 -0.50711656 -0.40286636 -0.46360251  0.52653843
#  -0.74304813  0.15560688 -0.64551359 -0.07274911 -0.00140307  0.26840979
#   0.20337746  0.16553789 -0.34812859  0.01833187  0.07457574 -0.34300187
#  -0.01154602 -0.13499266  0.03805841 -0.69270098  0.12317701 -0.21721932
#  -0.06532721 -0.00494521  0.13724719 -0.92559046 -0.39125717  0.74492759
#  -0.05698316 -0.38878381 -0.56901747  0.24829595  0.19856614  0.21320097
#   0.63177848 -0.26164463 -0.05718902  0.05561114 -0.15247075  0.22964783
#   0.25930673  0.06526547  0.4823539  -0.70429015  0.35425574  0.55340582
#   0.07124008  0.63598722 -0.28877348 -0.22284341 -0.42927557  0.58682275
#   0.7579183  -0.21720889  1.08766222 -0.51334715  0.00831539  0.29803216
#  -0.18051937  0.18562946 -0.3577778  -0.35275382  0.12210371  0.72638094
#   0.19961005  0.13974349 -0.61583549 -0.48942417 -0.14971599  0.15062326
#  -0.1293534  -0.55854189 -0.09252848  0.00513778 -0.74466497 -0.5433284
#  -0.1744605  -0.08753365 -0.24863927  0.50252259  0.03882907 -0.60412419
#   0.29830587  0.51975238  0.12245414  0.12973696]

# %% [markdown]
# ### Rede Siamesa para identificar similaridade entre as instâncias

# %% [markdown]
# ### Rever texto
# Iremos treinar um modelo para receber pares de sentença e gera um vetor de embeddings para cada sentença. Se as entidades presentes nas sentenças forem os mesmos, a distância entre os embeddings gerados deve ser pequena, caso o contrário, a distância deve ser alta.
# Ver: https://towardsdatascience.com/siamese-networks-introduction-and-implementation-2140e3443dee

# %% [markdown]
# Escolhendo modelo para carregar do TensorFlow HUB

# %%
bert_model_name = 'small_bert/bert_en_uncased_L-2_H-128_A-2' 

map_name_to_handle = {
    'bert_en_uncased_L-12_H-768_A-12':
        'https://tfhub.dev/tensorflow/bert_en_uncased_L-12_H-768_A-12/3',
    'bert_en_cased_L-12_H-768_A-12':
        'https://tfhub.dev/tensorflow/bert_en_cased_L-12_H-768_A-12/3',
    'bert_multi_cased_L-12_H-768_A-12':
        'https://tfhub.dev/tensorflow/bert_multi_cased_L-12_H-768_A-12/3',
    'small_bert/bert_en_uncased_L-2_H-128_A-2':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-2_H-128_A-2/1',
    'small_bert/bert_en_uncased_L-2_H-256_A-4':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-2_H-256_A-4/1',
    'small_bert/bert_en_uncased_L-2_H-512_A-8':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-2_H-512_A-8/1',
    'small_bert/bert_en_uncased_L-2_H-768_A-12':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-2_H-768_A-12/1',
    'small_bert/bert_en_uncased_L-4_H-128_A-2':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-4_H-128_A-2/1',
    'small_bert/bert_en_uncased_L-4_H-256_A-4':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-4_H-256_A-4/1',
    'small_bert/bert_en_uncased_L-4_H-512_A-8':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-4_H-512_A-8/1',
    'small_bert/bert_en_uncased_L-4_H-768_A-12':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-4_H-768_A-12/1',
    'small_bert/bert_en_uncased_L-6_H-128_A-2':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-6_H-128_A-2/1',
    'small_bert/bert_en_uncased_L-6_H-256_A-4':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-6_H-256_A-4/1',
    'small_bert/bert_en_uncased_L-6_H-512_A-8':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-6_H-512_A-8/1',
    'small_bert/bert_en_uncased_L-6_H-768_A-12':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-6_H-768_A-12/1',
    'small_bert/bert_en_uncased_L-8_H-128_A-2':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-8_H-128_A-2/1',
    'small_bert/bert_en_uncased_L-8_H-256_A-4':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-8_H-256_A-4/1',
    'small_bert/bert_en_uncased_L-8_H-512_A-8':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-8_H-512_A-8/1',
    'small_bert/bert_en_uncased_L-8_H-768_A-12':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-8_H-768_A-12/1',
    'small_bert/bert_en_uncased_L-10_H-128_A-2':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-10_H-128_A-2/1',
    'small_bert/bert_en_uncased_L-10_H-256_A-4':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-10_H-256_A-4/1',
    'small_bert/bert_en_uncased_L-10_H-512_A-8':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-10_H-512_A-8/1',
    'small_bert/bert_en_uncased_L-10_H-768_A-12':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-10_H-768_A-12/1',
    'small_bert/bert_en_uncased_L-12_H-128_A-2':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-12_H-128_A-2/1',
    'small_bert/bert_en_uncased_L-12_H-256_A-4':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-12_H-256_A-4/1',
    'small_bert/bert_en_uncased_L-12_H-512_A-8':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-12_H-512_A-8/1',
    'small_bert/bert_en_uncased_L-12_H-768_A-12':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-12_H-768_A-12/1',
    'albert_en_base':
        'https://tfhub.dev/tensorflow/albert_en_base/2',
    'electra_small':
        'https://tfhub.dev/google/electra_small/2',
    'electra_base':
        'https://tfhub.dev/google/electra_base/2',
    'experts_pubmed':
        'https://tfhub.dev/google/experts/bert/pubmed/2',
    'experts_wiki_books':
        'https://tfhub.dev/google/experts/bert/wiki_books/2',
    'talking-heads_base':
        'https://tfhub.dev/tensorflow/talkheads_ggelu_bert_en_base/1',
}

map_model_to_preprocess = {
    'bert_en_uncased_L-12_H-768_A-12':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'bert_en_cased_L-12_H-768_A-12':
        'https://tfhub.dev/tensorflow/bert_en_cased_preprocess/3',
    'small_bert/bert_en_uncased_L-2_H-128_A-2':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-2_H-256_A-4':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-2_H-512_A-8':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-2_H-768_A-12':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-4_H-128_A-2':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-4_H-256_A-4':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-4_H-512_A-8':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-4_H-768_A-12':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-6_H-128_A-2':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-6_H-256_A-4':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-6_H-512_A-8':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-6_H-768_A-12':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-8_H-128_A-2':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-8_H-256_A-4':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-8_H-512_A-8':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-8_H-768_A-12':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-10_H-128_A-2':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-10_H-256_A-4':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-10_H-512_A-8':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-10_H-768_A-12':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-12_H-128_A-2':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-12_H-256_A-4':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-12_H-512_A-8':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-12_H-768_A-12':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'bert_multi_cased_L-12_H-768_A-12':
        'https://tfhub.dev/tensorflow/bert_multi_cased_preprocess/3',
    'albert_en_base':
        'https://tfhub.dev/tensorflow/albert_en_preprocess/3',
    'electra_small':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'electra_base':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'experts_pubmed':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'experts_wiki_books':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'talking-heads_base':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
}

tfhub_handle_encoder = map_name_to_handle[bert_model_name]
tfhub_handle_preprocess = map_model_to_preprocess[bert_model_name]

print(f'BERT model selected           : {tfhub_handle_encoder}')
print(f'Preprocess model auto-selected: {tfhub_handle_preprocess}')
# Out:
# BERT model selected           : https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-2_H-128_A-2/1
# Preprocess model auto-selected: https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3

# %% [markdown]
# Construindo modelo que recebe as sentenças com as devidas marcações indicando as entidades e que tem como output o vetor OWL2Vec correspondete à essa entidade.

# %%
def build_model():
    #Texto de input
    text_input = tf.keras.layers.Input(shape=(), dtype=tf.string, name='text')
    # Camada de preprocessamento
    preprocessing_layer = hub.KerasLayer(tfhub_handle_preprocess, name='preprocessing')
    encoder_inputs = preprocessing_layer(text_input)
    # Camada BERT encode
    encoder = hub.KerasLayer(tfhub_handle_encoder, trainable=True, name='BERT_encoder')
    outputs = encoder(encoder_inputs)
    # Selecionando apenas o 'pooled_output' do BERT encode 
    net = outputs['pooled_output']
    # Camada de dropout
    net = tf.keras.layers.Dropout(0.1)(net)
    # Camada densa de saída, com a mesma dimensão do vetor OWL2Vec
    net = tf.keras.layers.Dense(100, activation=None, name='OWL2Vec_space')(net)
    return tf.keras.Model(text_input, net)

# %%
base_model = build_model()
base_model.summary()
tf.keras.utils.plot_model(base_model)
# Out:
# Model: "functional_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# text (InputLayer)               [(None,)]            0
# __________________________________________________________________________________________________
# preprocessing (KerasLayer)      {'input_mask': (None 0           text[0][0]
# __________________________________________________________________________________________________
# BERT_encoder (KerasLayer)       {'encoder_outputs':  4385921     preprocessing[0][0]
#                                                                  preprocessing[0][1]
#                                                                  preprocessing[0][2]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 128)          0           BERT_encoder[0][3]
# __________________________________________________________________________________________________
# OWL2Vec_space (Dense)           (None, 100)          12900       dropout_1[0][0]
# ==================================================================================================
# Total params: 4,398,821
# Trainable params: 4,398,820
# Non-trainable params: 1
# __________________________________________________________________________________________________

# %%
emb_size = 100

# Inputs para cada os modelos siameses
input_anchor = tf.keras.layers.Input(shape=(), dtype=tf.string, name='text_anchor')
input_positive = tf.keras.layers.Input(shape=(), dtype=tf.string, name='text_positive')
input_negative = tf.keras.layers.Input(shape=(), dtype=tf.string, name='text_negative')
input_URIvec =  tf.keras.layers.Input(shape=(emb_size), name='URIvec')

# Criando os modelos siameses
embedding_anchor = base_model(input_anchor)
embedding_positive = base_model(input_positive)
embedding_negative = base_model(input_negative)

# Concatenando os embeddings dos três modelos siameses
output = tf.keras.layers.concatenate([embedding_anchor, embedding_positive, embedding_negative, input_URIvec], axis=1)

siames_model = tf.keras.models.Model([input_anchor, input_positive, input_negative, input_URIvec], output)
siames_model.summary()
tf.keras.utils.plot_model(siames_model)
# Out:
# Model: "functional_7"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# text_anchor (InputLayer)        [(None,)]            0
# __________________________________________________________________________________________________
# text_positive (InputLayer)      [(None,)]            0
# __________________________________________________________________________________________________
# text_negative (InputLayer)      [(None,)]            0
# __________________________________________________________________________________________________
# functional_5 (Functional)       (None, 100)          4398821     text_anchor[0][0]
#                                                                  text_positive[0][0]
#                                                                  text_negative[0][0]
# __________________________________________________________________________________________________
# URIvec (InputLayer)             [(None, 100)]        0
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 400)          0           functional_5[0][0]
#                                                                  functional_5[1][0]
#                                                                  functional_5[2][0]
#                                                                  URIvec[0][0]
# ==================================================================================================
# Total params: 4,398,821
# Trainable params: 4,398,820
# Non-trainable params: 1
# __________________________________________________________________________________________________

# %% [markdown]
# # Rever o texto
# Vamos definir uma função de perda triplet definida como:
# $L = max(d_p - d_n + \alpha, 0)$
# Onde $d_p$ é a distância entre o vetor âncora e o vetor positivo, $d_n$ a distância entre o vetor âncora e o vetor negativo e $\alpha$ um parâmetro que indica o quanto queremos distanciar os dois vetores (a partir de um certo ponto, os dois vetores já estão afastados o suficiente, não sendo mais necessário aplicar uma perda a ser otimizada).
#
# **Versão com PetroOntoVec**
# Vamos definir uma função de perda triplet definida como:
# $L = d_{uri} + max(d_p - d_n + \alpha, 0)$
# Onde $d_{uri}$ é a distância entre o vetor âncora e o URIvec (proveniente da PetroOntoVec), $d_p$ é a distância entre o vetor âncora e o vetor positivo, $d_n$ a distância entre o vetor âncora e o vetor negativo e $\alpha$ um parâmetro que indica o quanto queremos distanciar os dois vetores (a partir de um certo ponto, os dois vetores já estão afastados o suficiente, não sendo mais necessário aplicar uma perda a ser otimizada).

# %%
# Definir a função de perda triplet
alpha = 0.05
#The values closer to 1 indicate greater dissimilarity. This makes it usable as a loss function in a setting where you try to maximize the proximity between predictions and targets.
cosine_loss = tf.keras.losses.CosineSimilarity(axis=1)

def triplet_loss(y_true, y_pred):
    anchor = y_pred[:,:emb_size]
    positive = y_pred[:,emb_size:2*emb_size]
    negative = y_pred[:,2*emb_size:3*emb_size]
    URIvec = y_pred[:,3*emb_size:]
    
    # Somamos 1 à cossine_loss para que vetores muito similares fique próximo de zero, vetores ortogonais fiquem proximos de 1 e inversos próximos de 2.
    URI_dist = 1 + cosine_loss(anchor, URIvec)
    positive_dist = 1 + cosine_loss(anchor, positive)
    negative_dist = 1 + cosine_loss(anchor, negative)
    
    #URI_dist = distance.cosine(anchor, URIvec)
    #positive_dist = distance.cosine(anchor, positive)
    #negative_dist = distance.cosine(anchor, negative)
    
    #URI_dist = 1 - dot([anchor, URIvec], axes=1, normalize=False)
    #positive_dist = 1 - dot([anchor, positive], axes=1, normalize=False)
    #negative_dist = 1 - dot([anchor, negative], axes=1, normalize=False)
    
    #positive_dist = tf.reduce_mean(tf.square(anchor - positive), axis=1)
    #negative_dist = tf.reduce_mean(tf.square(anchor - negative), axis=1)
    return (URI_dist + tf.maximum(positive_dist - negative_dist + alpha, 0.))

# array para ser usada como y_true na função de perda
y_true_treino = np.zeros((len(dataset_anchor_treino), 4*emb_size))
y_true_valid = np.zeros((len(dataset_anchor_valid), 4*emb_size))
#y_true_teste = np.zeros((len(dataset_anchor_teste), 4*emb_size))

# %%
siames_model.compile(loss=triplet_loss, optimizer='adam')

# %%
siames_model.fit(x=[dataset_anchor_treino, 
                    dataset_positive_treino, 
                    dataset_negative_treino, 
                    URIvec_anchor_treino], 
                 y=y_true_treino, ### train_X, train_Y, 
                           batch_size=32,
                 validation_data=([dataset_anchor_valid, 
                                   dataset_positive_valid,
                                   dataset_negative_valid,
                                   URIvec_anchor_valid], y_true_valid),
                 callbacks = tf.keras.callbacks.EarlyStopping(monitor="val_loss", patience=3, restore_best_weights=True),
                 epochs=25)
# Out:
# Epoch 1/25
# 388/388 [==============================] - 35s 90ms/step - loss: 0.3007 - val_loss: 0.2241
# Epoch 2/25
# 388/388 [==============================] - 34s 87ms/step - loss: 0.1552 - val_loss: 0.1366
# Epoch 3/25
# 388/388 [==============================] - 34s 87ms/step - loss: 0.1005 - val_loss: 0.1109
# Epoch 4/25
# 388/388 [==============================] - 34s 87ms/step - loss: 0.0777 - val_loss: 0.0963
# Epoch 5/25
# 388/388 [==============================] - 34s 87ms/step - loss: 0.0670 - val_loss: 0.0944
# Epoch 6/25
# 388/388 [==============================] - 34s 87ms/step - loss: 0.0600 - val_loss: 0.0872
# Epoch 7/25
# 388/388 [==============================] - 34s 87ms/step - loss: 0.0540 - val_loss: 0.0873
# Epoch 8/25
# 388/388 [==============================] - 34s 87ms/step - loss: 0.0515 - val_loss: 0.0859
# Epoch 9/25
# 388/388 [==============================] - 34s 87ms/step - loss: 0.0479 - val_loss: 0.0805
# Epoch 10/25
# 388/388 [==============================] - 34s 87ms/step - loss: 0.0457 - val_loss: 0.0830
# Epoch 11/25
# 388/388 [==============================] - 34s 87ms/step - loss: 0.0439 - val_loss: 0.0823
# Epoch 12/25
# 388/388 [==============================] - 34s 87ms/step - loss: 0.0424 - val_loss: 0.0794
# Epoch 13/25
# 388/388 [==============================] - 34s 86ms/step - loss: 0.0441 - val_loss: 0.0935
# Epoch 14/25
# 388/388 [==============================] - 34s 87ms/step - loss: 0.0441 - val_loss: 0.0808
# Epoch 15/25
# 388/388 [==============================] - 34s 86ms/step - loss: 0.0405 - val_loss: 0.0805

# %% [markdown]
# ### Predizendo os embedding das sentenças de teste com o modelo transformer base usado pela rede siamesa

# %%
embedding_dataset_teste = base_model.predict(teste_text)
#embedding_dataset_treino = base_model.predict(text_dataset_treino)

# %% [markdown]
# Vamos comparar o vetor predito pelo modelo treinado com o vetor OWL2Vec mais próximo, esperamos que ele seja referente a mesma label que está presente na sentença. A precisão é dada pelo números vetores preditos corretamente / número de predições

# %%
# Carregando Modelo OWL2Vec - 
PetroOntoVec = gensim.models.Word2Vec.load("../../Embeddings/PetroOntoVec/PetroOntoVec_simples/outputontology.embeddings")
name_onto = 'http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#'
len_name = len(name_onto)

# %%
sim = 1 - alpha

URI_linked_pred = []
URI_linked_true = []

for n in range(len(embedding_dataset_teste)):
    most_similar = PetroOntoVec.wv.most_similar([embedding_dataset_teste[n]], topn=1)
    for m in most_similar:
        # Só fazer predicção se similaridade for maior que "SIM"
        if m[1] > sim:
            URI_linked_pred.append(m[0][len_name-1:])
            #URI_linked_true.append(str(teste_ENT_URI[n]))
            URI_linked_true.append(teste_ENT_URI[n])
        #else:
        #    URI_linked.append('None')

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_recall_fscore_support

print(accuracy_score(URI_linked_true, URI_linked_pred))
print(precision_recall_fscore_support(URI_linked_true, URI_linked_pred, average='micro'))
# Out:
# 0.8582548136009832
# (0.8582548136009832, 0.8582548136009832, 0.8582548136009832, None)

# %%
#####  Ajustar o código para as URI anotadas no PetroNER
TP = 0
Total = 0
sim = 1 - alpha

for n in range(len(embedding_dataset_teste)):
    most_similar = PetroOntoVec.wv.most_similar([embedding_dataset_teste[n]], topn=1)
    for m in most_similar:
        # Só fazer predicção se similaridade for maior que "SIM"
        if m[1] > sim:
            Total = Total + 1
            
            if teste_ENT_URI[n] == m[0][len_name-1:]:
                TP = TP + 1
                
            else:
                print(teste_text[n])
                print('True URI: ', teste_ENT_URI[n])
                print('Pred URI: ', m[0][len_name-1:])
                print('-------------------')
                
                #Verifica se a URI está no PetroOntoVec (ontologia) 
            #    try:
            #        PetroOntoVec[name_onto[:-1] + teste_ENT_URI[n]]
            #    except:

            #        print(n)
            #        print (teste_ENT_URI[n])
            #        print(m[1], m[0])
            #        print(teste_text[n])
            #        print('---------------------------')

        #else:
            #Verifica se a URI está no PetroOntoVec (ontologia) 
            #try:
            #    PetroOntoVec[name_onto[:-1] + teste_ENT_URI[n]]
            #    print(n)
            #    print (teste_ENT_URI[n])
            #    print(m[1], m[0])
            #    print(teste_text[n])
            #    print('---------------------------')
                
            #except:
            #    pass
            #    print(n)
            #    print (teste_ENT_URI[n])
            #    print(m[1], m[0])
            #    print(teste_text[n])
            #    print('---------------------------')


print("Precisão: ", TP/Total)
print("Total dataset teste: ", len(embedding_dataset_teste))
print("Total predito: ", Total)
# Out:
# [ESTRUTURA_FÍSICA] discordâncias | Vail et al.( 1977) observaram evidências de onlap sobre [E] discordâncias [/E] regionais em seções sismicas dip através de bacias de margem passiva..
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_036
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_139
# -------------------
# [ESTRUTURA_FÍSICA] discordâncias | Flutuações do nível do mar foram consideradas como mecanismo principal no desenvolvimento de sequências deposicionais balizadas por [E] discordâncias [/E] de caráter reaional( fia. 1)..
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_036
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_139
# -------------------
# [ESTRUTURA_FÍSICA] discordâncias | Já no modelo de Vail, os limites de sequências são marcados por [E] discordâncias [/E] regionais e suas concordâncias relativas..
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_036
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_139
# -------------------
# [ESTRUTURA_FÍSICA] falha | Durante fases de nível( de base) baixo, fácies grossas acumulam-se em canais fluviais nas margens da bacia, em fan deltas adjacentes à [E] falha [/E] de borda e em deltas progradantes de pequenas dimensões( fig. 4)..
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_058
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_043
# -------------------
# [ESTRUTURA_FÍSICA] discordâncias | 2.2- Estratigrafia de Sequências da Formação Pendência, Bacia Potiguar Della Favera et al.( 1992) analisam a seção sin-rift da Bacia Potiguar, na qual identificaram quatro sequências balizadas por [E] discordâncias [/E] e suas concordâncias relativas dentro da Formação Pendência..
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_036
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_139
# -------------------
# [ESTRUTURA_FÍSICA] discordâncias | Uma tectono-sequência é balizada por [E] discordâncias [/E] regionais( fig. 5)..
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_036
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_139
# -------------------
# [ESTRUTURA_FÍSICA] discordâncias | Essas [E] discordâncias [/E] delimitam estratos gerados durante fases tectônicas distintas, servindo como pontos B. Geoci..
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_036
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_139
# -------------------
# [ESTRUTURA_FÍSICA] falhamentos | 2.4- Modelo de Prosser Prosser( 1993) reconhece a influência do tectonismo tanto na distribuição espacial como na evolução temporal de sistemas deposicionais presentes em bacias limitadas por [E] falhamentos [/E] ativos..
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_058
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_207
# -------------------
# [ESTRUTURA_FÍSICA] discordâncias | Ao longo de margens divergentes, [E] discordâncias [/E] regionais separam rochas depositadas sob diferentes regimes tectônicos( Uchupi e Emery, 1991)..
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_036
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_139
# -------------------
# [ESTRUTURA_FÍSICA] discordâncias | As [E] discordâncias [/E] do início do rift( rift onset unconformity, Falvey, 1974) e da separação continental( breakup unconformity, Falvey, 1974), reconhecidas em diferentes bacias rift do mundo, assinalam importantes mudangas de fases tectônicas, que resultam da evolução de placas litosféricas ao longo do tempo geológico..
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_036
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_139
# -------------------
# [ESTRUTURA_FÍSICA] discordâncias | As sequências balizadas por [E] discordâncias [/E], conforme definidas por Sloss para bacias intracratônicas( Sloss, 1963; 1988), representam outro exemplo de discordâncias regionais que limitam pacotes sedimentares..
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_036
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_139
# -------------------
# [ESTRUTURA_FÍSICA] discordâncias | As sequências balizadas por discordâncias, conforme definidas por Sloss para bacias intracratônicas( Sloss, 1963; 1988), representam outro exemplo de [E] discordâncias [/E] regionais que limitam pacotes sedimentares..
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_036
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_139
# -------------------
# [ESTRUTURA_FÍSICA] discordância | Nessas áreas, sujeitas a maiores taxas de subsidência e com maior lâmina d'água, a [E] discordância [/E] regional passa lateralmente a uma concordância relativa..
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_036
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_139
# -------------------
# [ESTRUTURA_FÍSICA] discordâncias | Utilizando-se a mesma metodologia para a análise de bacias do tipo rift, tenta-se, inicialmente, buscar as [E] discordâncias [/E] na margem flexural do riff e traçá-las em direção ao depocentro da bacia..
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_036
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_139
# -------------------
# [ESTRUTURA_FÍSICA] discordância | Mas qual [E] discordância [/E] será selecionada se a margem flexural está, de modo geral, sempre sujeita à erosão e bypass sedimentar?
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_036
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_139
# -------------------
# [FLUIDODATERRA_o] água do mar | O Glossário de Geologia( Bates e Jackson, 1987) define eustasia como o regime mundial do nível do mar e suas flutuações, causadas por mudanças absolutas na quantidade de [E] água do mar [/E], isto é, por flutuações da capa de gelo continental..
# True URI:  #water
# Pred URI:  #fluid_origin
# -------------------
# [UNIDADE_LITO] Membro Taquari | A seção testemunhada( figs. 2 e 3) abrange a parte inferior da Formação Riachuelo, [E] Membro Taquari [/E], e boa parte da Formação Muribeca, membros Oiteirinhos e 1- Serviço de Recursos Humanos( SEREC), Centro de Treinamento do Sul e Sudeste( CEN-SUD), Área de Geologia, Rua General Canabarro, 500, 20271-900, Maracanã, Rio de Janeiro, RJ, Brasil..
# True URI:  #membro_007
# Pred URI:  #formacao_242
# -------------------
# [ROCHA] carbonatos | A transição de sedimentação continental para’ marinha na Bacia de Sergipe teve início com a deposição em planície de sabkha dos evaporitos e [E] carbonatos [/E] laminados ou estromatolíticos do Membro Ibura..
# True URI:  #carbonatos
# Pred URI:  #Carboniferous
# -------------------
# [TEXTURA] estromatolíticos | A transição de sedimentação continental para’ marinha na Bacia de Sergipe teve início com a deposição em planície de sabkha dos evaporitos e carbonatos laminados ou [E] estromatolíticos [/E] do Membro Ibura..
# True URI:  #textura_052
# Pred URI:  #textura_046
# -------------------
# [ESTRUTURA_FÍSICA] maciços | Os primeiros sedimentos inequivocamente marinhos da seção amostrada são calcilutitos [E] maciços [/E] com ocasionais algas cianoficeas, que ocorrem nos testemunhos do poço 7-CP-252-SE acima dos 510m( fotos 3 e 4)..
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_023
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_139
# -------------------
# [UNIDADE_LITO] Membro Taquari | Tal caráter fossilifero e bioturbado prossegue nos calcilutitos e folhelhos cinzentos do [E] Membro Taquari [/E], acima..
# True URI:  #membro_007
# Pred URI:  #formacao_242
# -------------------
# [UNIDADE_LITO] Membro Taquari | Esta datação foi refinada por Koutsoukos( 1989) e Koutsoukos ef aí.( 1989), que relataram a presença de foraminiferos ptantônicos do subgênero Favusella, de idade necaptiana, nas rochas do Membro Oiteirinhos e da base do [E] Membro Taquari [/E]..
# True URI:  #membro_007
# Pred URI:  #formacao_242
# -------------------
# [UNIDADE_CRONO] Eo-Mesoalbiano | A seguir, comparou faunas de foraminiferos encontradas nas bacias costeiras brasileiras, para concluir por uma livre circulação das águas oceânicas a partir do [E] Eo-Mesoalbiano [/E]..
# True URI:  #Lower_Albian_Subage
# Pred URI:  #Middle_Albian_Subage
# -------------------
# [UNIDADE_LITO] Membro Oiterrinhos | Foto 67-CP-252-SE# 4 499,4 m. Formação Muribeca, [E] Membro Oiterrinhos [/E]..
# True URI:  #membro_044
# Pred URI:  #membro_010
# -------------------
# [ESTRUTURA_FÍSICA] maciço | Calcilutito [E] maciço [/E] fortemente bioturbado..
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_023
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_139
# -------------------
# [UNIDADE_LITO] Membro Taquari | PETROBRAS, Rio de Janeiro, 70( 1/4). 157-164, jan./ dez, Foto 8- 5-CPB-1A-SE 43 354,8 m. Formação Riachuelo, [E] Membro Taquari [/E]..
# True URI:  #membro_007
# Pred URI:  #formacao_242
# -------------------
# [UNIDADE_LITO] Membro Taquan | Foto 9- 7-CP-252-SE# 4 4937 m. Formação Riachueio, [E] Membro Taquan [/E]..
# True URI:  #membro_007
# Pred URI:  #formacao_242
# -------------------
# [ROCHA] carbonatos | FEIJÓ, F. J. Estudo dos [E] carbonatos [/E] Muribeca e Riachuelo no Alto de Aracaju- Bacia Sergipe- Alagoas..
# True URI:  #carbonatos
# Pred URI:  #Carboniferous
# -------------------
# [UNIDADE_CRONO] eojurássica | Na Bacia de Paris, por exemplo, em dados geoquímicos da seção geradora marinha [E] eojurássica [/E], obtidos em poços diferentes, nota-se claramente depleção no índice de hidrogênio acompanhada de um incremento na quantidade de hidrocarbonetos( determinado por extração) a partir de uma profundidade em torno de 2 000 m, indicando o início da geração de petróleo( Espitalié et al. 1988; fig. 5)..
# True URI:  #LowerJurassic
# Pred URI:  #Lower_Barremian_Subage
# -------------------
# [FLUIDODATERRA_i] betume | Evolução dos parâmetros HC( [E] betume [/E] extraído), índice de hidrogênio( IH), taxa de transformação( TT) e índice de produção( IP) em função da profundidade( Espitalié et al. 1985)..
# True URI:  #heavy_oil
# Pred URI:  #carbon_dioxide
# -------------------
# [FLUIDODATERRA_i] betumes | Na pirólise de rochas geradoras com [E] betumes [/E] ricos em parafinas de alto peso molecular( C39) e em compostos heteroatômicos, significativa parcela dos hidrocarbonetos livres é volatilizada somente a temperaturas mais elevadas, correspondentes às vigentes na fase de aquisição do pico S,..
# True URI:  #heavy_oil
# Pred URI:  #oil
# -------------------
# [FLUIDODATERRA_i] betumes | Na pirólise de rochas geradoras com [E] betumes [/E] ricos em parafinas de alto peso molecular( > C36) e em compostos heteroatômicos, significativa parcela dos hidrocarbonetos livres é volatilizada somente a temperaturas mais elevadas, correspondentes às vigentes na fase de aquisição do pico S,..
# True URI:  #heavy_oil
# Pred URI:  #oil
# -------------------
# [FLUIDO] fluidos | Esta contaminação pode ser devida tanto à impregnação das amostras por [E] fluidos [/E] de perfuração à base de óleo, quanto a processos naturais como a migração secundária de petróleo gerado em outras áreas da bacia..
# True URI:  #earth_fluid
# Pred URI:
# -------------------
# [UNIDADE_CRONO] andares Rio da Serra | Para isto, selecionaram-se dois exemplos de seções geradoras: Cretáceo Inferior( [E] andares Rio da Serra [/E] a Jiquiá) de uma bacia rift da costa leste e Albo-cenomaniano de uma bacia marginal da costa nordeste..
# True URI:  #Rio_da_serra_Age
# Pred URI:  #Neoriodaserra_Subage
# -------------------
# [UNIDADE_CRONO] Cretáceo | Gerador do [E] Cretáceo [/E] Inferior
# True URI:  #LowerCretaceous
# Pred URI:  #Cretaceous
# -------------------
# [UNIDADE_CRONO] Pleistoceno/Holoceno | Os testemunhos a pistão, relativamente curtos, serviram para delimitar com mais precisão o limite [E] Pleistoceno/Holoceno [/E] em várias áreas do talude da Bacia de Campos e calibrar o biorizonte desaparecimento de Pulleniatina obliquiloculata..
# True URI:  #Holocene
# Pred URI:  #Pleistocene
# -------------------
# [UNIDADE_CRONO] Pleistoceno/Holoceno | Los núcleos con piston, relativamente cortos, sirvieron para delimitarcon más precisión el límite [E] Pleistoceno/Holoceno [/E] en varias áreas del talud de la Cuenca de Campos y calibrar el bio-horizonte desaparecimiento de Pulleniatina obliquiloculata..
# True URI:  #Holocene
# Pred URI:  #Pleistocene
# -------------------
# [BACIA] bacias | Mas é nas [E] bacias [/E] oceânicas que a natureza de tais processos está bem representada..
# True URI:  #basin
# Pred URI:  #POCO_CD_POCO_023090
# -------------------
# [UNIDADE_CRONO] Pleistoceno/Holoceno | Portanto, ao se buscar a construção de curvas paleoclimáticas e data bem marcados para o limite [E] Pleistoceno/Holoceno [/E], e limites entre zonas e subzonas do Pleistoceno, podem ser obtidos pelo método mais rápido, por meio do controle presença / ausência/ abundância relativa do plexo Globorotalia menardii..
# True URI:  #Holocene
# Pred URI:  #Pleistocene
# -------------------
# [UNIDADE_CRONO] Pleistoceno/Holoceno | O plexo Pulleniatina está presente na Subzona Y2 e desaparece completamente na Subzona Y1, reaparecendo bem próximo do limite [E] Pleistoceno/Holoceno [/E]..
# True URI:  #Holocene
# Pred URI:  #Pleistocene
# -------------------
# [UNIDADE_CRONO] Pleistoceno/Holoceno | Os testemunhos a pistão, relativamente curtos( fig. 1 e quadro IJ), serviram para registrar com mais precisão o limite [E] Pleistoceno/Holoceno [/E] em várias áreas do talude da Bacia de Campos e, eventualmente, identificar o datum Pulleniatina, uma vez que nenhum deles atingiu a Zona X..
# True URI:  #Holocene
# Pred URI:  #Pleistocene
# -------------------
# [UNIDADE_CRONO] Pleistoceno/Holoceno | Nas figuras de 9 a 14 demonstram-se graficamente, por meio de perfil, o limite [E] Pleistoceno/Holoceno [/E] para cada testemunho e, no quadro V, as taxas de sedimentação calculadas..
# True URI:  #Holocene
# Pred URI:  #Pleistocene
# -------------------
# [UNIDADE_CRONO] Pleistoceno/Holoceno | Em três testemunhos de Marlim( 9-PC-04, 9-PC-06 e 14-PC-06) e em um testemunho de Albacora( 5-PC-29), a determinação do limite [E] Pleistoceno/Holoceno [/E]— com base em foraminíferos planctônicos— foi coerente com as datações absolutas obtidas pelo método C-14( figs. 9, 12 e 13)..
# True URI:  #Holocene
# Pred URI:  #Pleistocene
# -------------------
# [NÃOCONSOLID] cascalho | No testemunho 9-PC-09, há um hiato entre a facies Cbi( [E] cascalho [/E] bioclástico) e Lci( lama cinza-esverdeada com intercalações) e no 14-PC-01 entre um estreito intervalo composto por ALs( areia lamosa siliciclástica) e Lci( Caddah, 1991)..
# True URI:  #gravel
# Pred URI:  #silt
# -------------------
# [UNIDADE_CRONO] Holoceno/Pleistoceno | Fig. 11- Perfil BB’- Correlação entre testemunhos a pistão, limite [E] Holoceno/Pleistoceno [/E], datum Pulleniatina e facies sedimentares.( Lâmina d'água em metros e comprimento dos testemunhos em centímetros)..
# True URI:  #Pleistocene
# Pred URI:  #Holocene
# -------------------
# [UNIDADE_CRONO] Pleistoceno/Holoceno | Para este testemunho, os foraminiferos marcam o limite [E] Pleistoceno/Holoceno [/E]( 11 000 anos) entre as amostras 10 e 15 cm e o desaparecimento do plexo Pulleniatina entre as amostras 340 e 360 cm..
# True URI:  #Holocene
# Pred URI:  #Pleistocene
# -------------------
# [UNIDADE_CRONO] Holoceno/Pleistoceno | Fig. 14- Perfil EE ’- Correlação entre testemunhos a pistão, limite [E] Holoceno/Pleistoceno [/E], datum Pulleniatina e facies sedimentares.( Lâmina d'água em metros e comprimento dos testemunhos em centímetros)..
# True URI:  #Pleistocene
# Pred URI:  #Holocene
# -------------------
# [UNIDADE_CRONO] Pleistoceno/Holoceno | Os testemunhos a pistão, relativamente curtos, serviram para registrar com mais precisão o limite [E] Pleistoceno/Holoceno [/E] em várias áreas do talude da Bacia de Campos e, eventualmente, identificar o biorizonte Pulleniatina, uma vez que nenhum deles atingiu a Zona X..
# True URI:  #Holocene
# Pred URI:  #Pleistocene
# -------------------
# [UNIDADE_CRONO] Pleistoceno/Holoceno | Os testemunhos a pistão, relativamente curtos, serviram para registrar com mais precisão o limite [E] Pleistoceno/Holoceno [/E] em várias áreas do talude da Bacia de Campos e, eventualmente, identificar o biorizonte Pulleniatina, uma vez que nenhum deles atingiu a Zona X..
# True URI:  #Holocene
# Pred URI:  #Pleistocene
# -------------------
# [UNIDADE_CRONO] Pleistoceno/Holoceno | Dois deles apresentam um hiato abaixo do limite [E] Pleistoceno/Holoceno [/E], onde estariam faltando cerca de 30 m de sedimentos..
# True URI:  #Holocene
# Pred URI:  #Pleistocene
# -------------------
# [BACIA] bacia | A estratigrafia do Mesozóico no Rifte do Recôncavo-Tucano-Jatobá é o resultado da própria evolução tectônica da [E] bacia [/E], podendo ser dividida em seqüências depositadas nas fases pré-rifte, sin-rifte e pós-rifte..
# True URI:  #basin
# Pred URI:  #stratigraphic_well
# -------------------
# [UNIDADE_CRONO] Rio da Serra | Tendo por base o conteúdo de ostracodes destas rochas, Viana et al.( 1971) propuseram a Série Recôncavo, composta de seis andares locais: Dom João, [E] Rio da Serra [/E], Aratu, Buracica, Jiquiá e Alagoas..
# True URI:  #Rio_da_serra_Age
# Pred URI:  #Neoriodaserra_Subage
# -------------------
# [BACIA] Bacia do Gabão | Figure da bacia, como indicam depósitos correlatos que existem em outras bacias brasileiras( por exemplo, bacias do Araripe, Sergipe-Alagoas, Camamu e Almada), como também ao longo do Oeste africano( por exemplo, [E] Bacia do Gabão [/E])..
# True URI:  #INTER_BACIA_017
# Pred URI:  #CAMP_CD_CAMPO_0523
# -------------------
# [ESTRUTURA_FÍSICA] falha | O principal deles foi um sistema flúvio-deltaico-lacustre( longitudinal a oblíquo) proveniente da Bacia do Tucano, que depositou folhelhos prodeltaicos e arenitos turbidíticos; o secun-dário, transversal à bacia, consistiu em leques conglomeráticos derivados da erosão do bloco alto da [E] falha [/E] de borda..
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_058
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_043
# -------------------
# [BACIA] Gabão | Neste período acumularam-se estratos que constituem os andares Rio da Serra Inferior ao Jiquiá, com unidades equivalentes nas bacias da margem atlântica da América do Sul( Sergipe-Alagoas, Camamu e Almada) e da África( [E] Gabão [/E])..
# True URI:  #INTER_BACIA_017
# Pred URI:  #CAMP_CD_CAMPO_0523
# -------------------
# [UNIDADE_CRONO] Rio da Serra Médio | Durante uma fase de bacia faminta, nos depocentros foram depositados turbiditos lon-gitudinais e transversais do Membro Gomo( Formação Candeias, [E] Rio da Serra Médio [/E]), juntamente com folhelhos lacustres( Da Silva et al. 2000), incluindo sucessões de arenitos laminados e maciços( Bruhn, 1999)..
# True URI:  #Mesoriodaserra_Age
# Pred URI:  #Neoriodaserra_Subage
# -------------------
# [ESTRUTURA_FÍSICA] maciços | Durante uma fase de bacia faminta, nos depocentros foram depositados turbiditos lon-gitudinais e transversais do Membro Gomo( Formação Candeias, Rio da Serra Médio), juntamente com folhelhos lacustres( Da Silva et al. 2000), incluindo sucessões de arenitos laminados e [E] maciços [/E]( Bruhn, 1999)..
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_023
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_139
# -------------------
# [UNIDADE_LITO] Formação Maracangalha | Em seguida, durante o Neo-Rio da Serra, uma contínua sedimentação de espessos arenitos deltaicos exerceu forte sobrecarga sobre folhelhos da [E] Formação Maracangalha [/E], pressurizando-os e resultando em diápiros de folhelhos associados a falhas de crescimento..
# True URI:  #formacao_338
# Pred URI:  #BASE_CD_BACIA_076
# -------------------
# [ESTRUTURA_FÍSICA] falhas | Em seguida, durante o Neo-Rio da Serra, uma contínua sedimentação de espessos arenitos deltaicos exerceu forte sobrecarga sobre folhelhos da Formação Maracangalha, pressurizando-os e resultando em diápiros de folhelhos associados a [E] falhas [/E] de crescimento..
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_058
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_043
# -------------------
# [ESTRUTURA_FÍSICA] maciços | Nesta última unidade ocorrem espessos pacotes de arenitos [E] maciços [/E] e fluidizados dos membros Pitanga e Caruaçu, depositados ao longo dos depocentros mais orientais do gráben..
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_023
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_139
# -------------------
# [ROCHA] carbonatos | A diminuição da taxa de subsidência, no período que inclui as idades Rio da Serra e Aratu, pos-sibilitou que deltas progradassem de NNW sobre as plataformas existentes na margem flexural do rifte, preenchendo os depocentros com arenitos, siltitos, folhelhos e ocasionais [E] carbonatos [/E] do Grupo Ilhas, constituído pela Formação Marfim, Membro Catu, e Formação Pojuca..
# True URI:  #carbonatos
# Pred URI:  #Carboniferous
# -------------------
# [BACIA] bacias | Durante o Eoaratu, uma queda no nível do lago, tectonicamente induzida, originou um canyon na porção oeste das [E] bacias [/E] do Tucano Sul e Recôncavo( Bueno, 1987), onde acumu-laram-se os arenitos e folhelhos da Formação Taquipe( Netto e Oliveira, 1985; fig. 5)..
# True URI:  #BASE_CD_BACIA_230
# Pred URI:  #basin
# -------------------
# [UNIDADE_LITO] Formação Taquipe | Durante o Eoaratu, uma queda no nível do lago, tectonicamente induzida, originou um canyon na porção oeste das bacias do Tucano Sul e Recôncavo( Bueno, 1987), onde acumu-laram-se os arenitos e folhelhos da [E] Formação Taquipe [/E]( Netto e Oliveira, 1985; fig. 5)..
# True URI:  #formacao_328
# Pred URI:  #formacao_242
# -------------------
# [ESTRUTURA_FÍSICA] discordância | Uma [E] discordância [/E] angular separa a tectono-seqüência do Cretáceo Inferior( Da Silva, 1993) dos depósitos aluviais de conglomerados, arenitos e ocasionais folhelhos e calcários da Formação Marizal, de idade Alagoas..
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_036
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_139
# -------------------
# [ESTRUTURA_FÍSICA] discordância | A [E] discordância [/E] na base da Formação Marizal correlaciona-se com a discordância de ruptura continental( break up unconformity) que comumente precede a fase de deriva continental..
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_036
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_139
# -------------------
# [ESTRUTURA_FÍSICA] discordância | A discordância na base da Formação Marizal correlaciona-se com a [E] discordância [/E] de ruptura continental( break up unconformity) que comumente precede a fase de deriva continental..
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_036
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_139
# -------------------
# [BACIA] bacias | Esta mesma superfície erosiva é reconhecida não-apenas nas [E] bacias [/E] da margem continental leste brasileira( Kiang et al. 1988), como também nas suas correspondentes africanas( por exemplo, Bacia do Gabão; Teisserenc e Villemin, 1989)..
# True URI:  #basin
# Pred URI:  #CAMP_CD_CAMPO_0932
# -------------------
# [BACIA] Bacia do Gabão | Esta mesma superfície erosiva é reconhecida não-apenas nas bacias da margem continental leste brasileira( Kiang et al. 1988), como também nas suas correspondentes africanas( por exemplo, [E] Bacia do Gabão [/E]; Teisserenc e Villemin, 1989)..
# True URI:  #INTER_BACIA_017
# Pred URI:  #CAMP_CD_CAMPO_0523
# -------------------
# [UNIDADE_CRONO] Plio-ceno-Pleistoceno | Sobrepostos a estes, co-brindo boa parte da porção sul do rifte, bem como em larga porção da costa brasileira, ocorrem arenitos continentais do Grupo Barreiras( [E] Plio-ceno-Pleistoceno [/E]), com menos de 100 m de espessura preservada..
# True URI:  #Pliocene
# Pred URI:  #Pleistocene
# -------------------
# [ESTRUTURA_FÍSICA] falha | O trend geral NE-SW dos blocos que constituem a Bacia do Recôncavo é interrompido por uma zona de [E] falha [/E] transversal orientada na direção NW-SE, interpretada tradicionalmente como uma falha de transferência( Milani e Davison, 1988; Aragão, 1994), a Falha de Mata-Catu..
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_058
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_043
# -------------------
# [ESTRUTURA_FÍSICA] falha | O trend geral NE-SW dos blocos que constituem a Bacia do Recôncavo é interrompido por uma zona de falha transversal orientada na direção NW-SE, interpretada tradicionalmente como uma [E] falha [/E] de transferência( Milani e Davison, 1988; Aragão, 1994), a Falha de Mata-Catu..
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_058
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_043
# -------------------
# [ESTRUTURA_FÍSICA] Falha | O trend geral NE-SW dos blocos que constituem a Bacia do Recôncavo é interrompido por uma zona de falha transversal orientada na direção NW-SE, interpretada tradicionalmente como uma falha de transferência( Milani e Davison, 1988; Aragão, 1994), a [E] Falha [/E] de Mata-Catu..
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_058
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_043
# -------------------
# [ESTRUTURA_FÍSICA] falha | Esta zona de [E] falha [/E] controla o principal trend de petróleo da bacia..
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_058
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_043
# -------------------
# [UNIDADE_CRONO] Rio da Serra Médio | O primeiro evento teria acontecido durante o [E] Rio da Serra Médio [/E]( Berriasiano), quando distensão E-W ao longo do Rifte Recôncavo-Tucano-Jatobá e bacias adjacentes teria sido acomodada por movimento sinistral ao longo do lineamento de Pernambuco/ Ngaoundere( fig. 8a), uma vez que o bloco a norte teria ficado relativamente fixo em relação ao bloco meridional..
# True URI:  #Mesoriodaserra_Age
# Pred URI:  #Neoriodaserra_Subage
# -------------------
# [ESTRUTURA_FÍSICA] discordância | O modelo postula a seguinte sucessão de eventos:( a) rápido soerguimento regional decorrente do rebote elástico ao final da fase sin-rifte, originando uma [E] discordância [/E] angular( break up unconformity);( b) subsidência térmica pós-rifte contínua por 90 milhões de anos( Aptiano ao Oligoceno), que resultou em mais de 1 km de sedimentos acumulados e que ultrapas-sariam a margem da bacia;( c) soerguimento durante o Oligoceno seguido por erosão da maior parte dos depósitos pós-rifte..
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_036
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_139
# -------------------
# [ESTRUTURA_FÍSICA] estratificações cruzadas de baixo ângulo | Os arenitos ocorrem com [E] estratificações cruzadas de baixo ângulo [/E] e laminações do tipo wavy..
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_006
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_139
# -------------------
# [ESTRUTURA_FÍSICA] laminações | Os arenitos ocorrem com estratificações cruzadas de baixo ângulo e [E] laminações [/E] do tipo wavy..
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_048
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_207
# -------------------
# [ESTRUTURA_FÍSICA] wavy | Os arenitos ocorrem com estratificações cruzadas de baixo ângulo e laminações do tipo [E] wavy [/E]..
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_223
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_143
# -------------------
# [ESTRUTURA_FÍSICA] lenticulares | As estruturas sedimentares estão profundamente mas-caradas pela diagênese, mas a presença de estruturas sedimentares [E] lenticulares [/E] e onduladas sugerem condições marinhas rasas, influenciadas pela maré..
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_066
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_207
# -------------------
# [ESTRUTURA_FÍSICA] Falhas | [E] Falhas [/E] métricas e centimétricas são comuns nesta seção..
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_058
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_043
# -------------------
# [UNIDADE_LITO] membros Boipeba | PONTO 2- Contato entre os [E] membros Boipeba [/E] e Capianga da Formação Aliança( Andar Dom João, Jurássico Superior; fig 15)..
# True URI:  #membro_071
# Pred URI:  #BASE_CD_BACIA_236
# -------------------
# [UNIDADE_LITO] Membro Boipeba | Descrição: A partir da base( fig 16), os folhelhos vermelhos do Membro Cazumba( Formação Afligidos- Af, Permiano) estão sotopostos a arenitos flúvio-eólicos, finos a médios do [E] Membro Boipeba [/E]- Bo- da Formação Aliança( Jurássico Superior)..
# True URI:  #membro_071
# Pred URI:  #BASE_CD_BACIA_236
# -------------------
# [ESTRUTURA_FÍSICA] estratificação cruzada acanalada | Os arenitos exibem [E] estratificação cruzada acanalada [/E] de médio a grande porte, em transição no sentido do topo para folhelhos lacustres avermelhados do Membro Capianga- Cp( Formação Aliança, Jurássico Superior)..
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_127
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_139
# -------------------
# [ESTRUTURA_FÍSICA] falha | madas na estrutura em rollover variam de 25º, próximo à [E] falha [/E], para 10º( mergulho regional) cerca de 22 m a sul da falha..
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_058
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_115
# -------------------
# [ESTRUTURA_FÍSICA] falha | madas na estrutura em rollover variam de 25º, próximo à falha, para 10º( mergulho regional) cerca de 22 m a sul da [E] falha [/E]..
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_058
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_043
# -------------------
# [ESTRUTURA_FÍSICA] falha | A espessura de uma camada-chave de arenitos varia de 0,2 a 2,7 m com a proximidade da [E] falha [/E] no bloco baixo..
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_058
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_043
# -------------------
# [ESTRUTURA_FÍSICA] falha | Observações importantes:• crescimento dos estratos• geometria lístrica da [E] falha [/E]• camadas contorcidas• variações de mergulhos• estratificações cruzadas de grande porte PONTO 4- Membro Gomo, Formação Candeias( Andar Rio da Serra, Cretáceo Inferior; fig. 20)..
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_058
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_043
# -------------------
# [ESTRUTURA_FÍSICA] estratificações cruzadas | Observações importantes:• crescimento dos estratos• geometria lístrica da falha• camadas contorcidas• variações de mergulhos• [E] estratificações cruzadas [/E] de grande porte PONTO 4- Membro Gomo, Formação Candeias( Andar Rio da Serra, Cretáceo Inferior; fig. 20)..
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_004
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_139
# -------------------
# [UNIDADE_CRONO] Andar Rio da Serra | Observações importantes:• crescimento dos estratos• geometria lístrica da falha• camadas contorcidas• variações de mergulhos• estratificações cruzadas de grande porte PONTO 4- Membro Gomo, Formação Candeias( [E] Andar Rio da Serra [/E], Cretáceo Inferior; fig. 20)..
# True URI:  #Rio_da_serra_Age
# Pred URI:  #Neoriodaserra_Subage
# -------------------
# [ESTRUTURA_FÍSICA] septárias | Concre-ções de [E] septárias [/E] são comuns..
# True URI:  None
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_207
# -------------------
# [ESTRUTURA_FÍSICA] estratificações | Os arenitos eólicos exibem [E] estratificações [/E] de médio a grande porte, estruturas características de fluxo de grãos( fig. 23) e laminações cruzadas transladantes..
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_126
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_139
# -------------------
# [ESTRUTURA_FÍSICA] laminações cruzadas | Os arenitos eólicos exibem estratificações de médio a grande porte, estruturas características de fluxo de grãos( fig. 23) e [E] laminações cruzadas [/E] transladantes..
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_169
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_139
# -------------------
# [ESTRUTURA_FÍSICA] estratificação cruzada acanalada | Para o topo( fig. 24), arenitos fluviais grossos apresentam [E] estratificação cruzada acanalada [/E]..
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_127
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_139
# -------------------
# [ESTRUTURA_FÍSICA] estratificações cruzadas | Descrição: Neste ponto, arenitos pobremente selecionados com [E] estratificações cruzadas [/E] caracterizam barras retrabalhadas pela ação eólica( fig. 26)..
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_004
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_139
# -------------------
# [ESTRUTURA_FÍSICA] falhas | A repetição de elevações topográficas sustentadas pela Formação Sergi ao longo da rodovia BR-324 deve-se a blocos basculados mergulhando para leste( fig. 28), rotacionados por [E] falhas [/E] sintéticas cujos planos mergulham para oeste..
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_058
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_043
# -------------------
# [ESTRUTURA_FÍSICA] estratificações cruzadas tabulares | Observações importantes:• [E] estratificações cruzadas tabulares [/E] e acanaladas• retrabalhamento eólico• depósito de caliche• línguas de fluxo de grão
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_010
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_139
# -------------------
# [ESTRUTURA_FÍSICA] acanaladas | Observações importantes:• estratificações cruzadas tabulares e [E] acanaladas [/E]• retrabalhamento eólico• depósito de caliche• línguas de fluxo de grão
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_127
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_114
# -------------------
# [ESTRUTURA_FÍSICA] estratificação | Detalhe da [E] estratificação [/E] na Formação Sergi..
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_126
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_139
# -------------------
# [UNIDADE_CRONO] andares Rio da Serra | PONTO 7- Leques conglomeráticos da Formação Salvador( [E] andares Rio da Serra [/E] ao Jiquiá, Cretáceo Inferior; fig. 29)..
# True URI:  #Rio_da_serra_Age
# Pred URI:  #Neoriodaserra_Subage
# -------------------
# [ESTRUTURA_FÍSICA] falhas | Salvador associados ao sistema de [E] falhas [/E] da borda do rifte..
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_058
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_043
# -------------------
# [NÃOCONSOLID] seixos | Matacões, calhaus e [E] seixos [/E] de gnaisses, granulitos, quartzitos e calcários são os constituintes mais comuns do arcabouço..
# True URI:  #cobbles
# Pred URI:  #silt
# -------------------
# [UNIDADE_LITO] Formação Maracangalha | Figura Vista dos turbiditos lacustres da [E] Formação Maracangalha [/E]..
# True URI:  #formacao_338
# Pred URI:  #BASE_CD_BACIA_076
# -------------------
# [ESTRUTURA_FÍSICA] Falhas | [E] Falhas [/E] normais( fig. 35) e diques de areia são também comuns..
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_058
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_043
# -------------------
# [ESTRUTURA_FÍSICA] estratificações | Seção vertical esquemática no Ponto 8, com aspectos das [E] estratificações [/E] dos corpos arenosos..
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_126
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_139
# -------------------
# [ESTRUTURA_FÍSICA] maciços | PONTO 9- Arenitos [E] maciços [/E] do Membro Pitanga( Formação Maracangalha, Andar Rio da Serra, Cretáceo Inferior; fig. 36)..
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_023
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_139
# -------------------
# [UNIDADE_LITO] Formação Maracangalha | PONTO 9- Arenitos maciços do Membro Pitanga( [E] Formação Maracangalha [/E], Andar Rio da Serra, Cretáceo Inferior; fig. 36)..
# True URI:  #formacao_338
# Pred URI:  #BASE_CD_BACIA_076
# -------------------
# [UNIDADE_CRONO] Andar Rio da Serra | PONTO 9- Arenitos maciços do Membro Pitanga( Formação Maracangalha, [E] Andar Rio da Serra [/E], Cretáceo Inferior; fig. 36)..
# True URI:  #Rio_da_serra_Age
# Pred URI:  #Neoriodaserra_Subage
# -------------------
# [ESTRUTURA_FÍSICA] maciços | Descrição: O Membro Pitanga é composto de arenitos muito finos, argilosos, [E] maciços [/E], exibindo estrutura“ cerebróide”( fig. 37)..
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_023
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_139
# -------------------
# [ESTRUTURA_FÍSICA] maciços | Descrição: Nesta exposição, arenitos [E] maciços [/E], fechados, gerados por fluxos de detritos e extrema fluidização caracterizam o Membro Caruaçu da Formação Maracangalha..
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_023
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_139
# -------------------
# [UNIDADE_LITO] Membro Caruaçu | Descrição: Nesta exposição, arenitos maciços, fechados, gerados por fluxos de detritos e extrema fluidização caracterizam o [E] Membro Caruaçu [/E] da Formação Maracangalha..
# True URI:  #membro_005
# Pred URI:  #membro_010
# -------------------
# [UNIDADE_LITO] Formação Maracangalha | Descrição: Nesta exposição, arenitos maciços, fechados, gerados por fluxos de detritos e extrema fluidização caracterizam o Membro Caruaçu da [E] Formação Maracangalha [/E]..
# True URI:  #formacao_338
# Pred URI:  #BASE_CD_BACIA_076
# -------------------
# [ESTRUTURA_FÍSICA] estruturas de chama | Estruturas de carga, [E] estruturas de chama [/E] e pseudonódulos caracterizam contatos entre as camadas..
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_038
# Pred URI:  #geological_structure
# -------------------
# [ESTRUTURA_FÍSICA] estratificações | Também, corpos de arenitos tabulares exibem acamamento gradacional, fluidização, [E] estratificações [/E] paralelas e cruzadas, e laminações cruzadas..
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_126
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_139
# -------------------
# [ESTRUTURA_FÍSICA] laminações cruzadas | Também, corpos de arenitos tabulares exibem acamamento gradacional, fluidização, estratificações paralelas e cruzadas, e [E] laminações cruzadas [/E]..
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_169
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_139
# -------------------
# [ESTRUTURA_FÍSICA] maciços | É notável a alternância entre arenitos [E] maciços [/E] e tabulares, uma condição que se assemelha àquela encontrada em campos de gás da bacia; os corpos tabulares apresentam melhor desempenho como reservatório do que os maciços..
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_023
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_139
# -------------------
# [ESTRUTURA_FÍSICA] maciços | É notável a alternância entre arenitos maciços e tabulares, uma condição que se assemelha àquela encontrada em campos de gás da bacia; os corpos tabulares apresentam melhor desempenho como reservatório do que os [E] maciços [/E]..
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_023
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_139
# -------------------
# [ESTRUTURA_FÍSICA] maciços | Contato entre os arenitos [E] maciços [/E] e a seção de arenitos estratificados do Membro Caruaçu..
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_023
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_139
# -------------------
# [UNIDADE_LITO] Membro Caruaçu | Contato entre os arenitos maciços e a seção de arenitos estratificados do [E] Membro Caruaçu [/E]..
# True URI:  #membro_005
# Pred URI:  #membro_010
# -------------------
# [UNIDADE_LITO] Formação Maracangalha | PONTO 11- Diápiro de Cinzento( [E] Formação Maracangalha [/E], Andar Rio da Serra, Cretáceo Inferior) e depósitos pós-rifte( Formação Marizal, Andar Alagoas, Aptiano; fig. 40)..
# True URI:  #formacao_338
# Pred URI:  #BASE_CD_BACIA_076
# -------------------
# [UNIDADE_CRONO] Andar Rio da Serra | PONTO 11- Diápiro de Cinzento( Formação Maracangalha, [E] Andar Rio da Serra [/E], Cretáceo Inferior) e depósitos pós-rifte( Formação Marizal, Andar Alagoas, Aptiano; fig. 40)..
# True URI:  #Rio_da_serra_Age
# Pred URI:  #Neoriodaserra_Subage
# -------------------
# [UNIDADE_LITO] Formação Maracangalha | Descrição: Diápiros de folhelhos são comuns na bacia, e a [E] Formação Maracangalha [/E] é a unidade que os origina..
# True URI:  #formacao_338
# Pred URI:  #BASE_CD_BACIA_076
# -------------------
# [ESTRUTURA_FÍSICA] discordância | Ao longo da superfície de [E] discordância [/E] ocorre exsu-dação de óleo e sulfetos associados..
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_036
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_139
# -------------------
# [ESTRUTURA_FÍSICA] Discordância | [E] Discordância [/E] angular( break up unconformity)..
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_036
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_139
# -------------------
# [ESTRUTURA_FÍSICA] Falhas | [E] Falhas [/E] de crescimento afetando a Formação São Sebastião..
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_058
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_043
# -------------------
# [ESTRUTURA_FÍSICA] Falhas | PONTO 12- [E] Falhas [/E] de crescimento na Formação São Sebastião( andares Buracica e Jiquiá, Cretáceo Inferior; fig. 43)..
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_058
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_043
# -------------------
# [ESTRUTURA_FÍSICA] falhas | Descrição: Ocorrem duas [E] falhas [/E] de crescimento exibindo fluxo de massa dos folhelhos e deformação associada( fig. 44)..
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_058
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_043
# -------------------
# [ESTRUTURA_FÍSICA] falhas | Devido à proximidade com o Diápiro de Cinzento, estes folhelhos fos-silíferos e ricos em matéria orgânica podem ser interpretados como rollers presentes nos blocos altos das [E] falhas [/E]..
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_058
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_043
# -------------------
# [ESTRUTURA_FÍSICA] falha | Espessuras de camadas-chave aumentam em direção ao plano de [E] falha [/E] no bloco baixo..
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_058
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_043
# -------------------
# [ESTRUTURA_FÍSICA] falhas | Observações importantes:• geometria das [E] falhas [/E] e das camadas• deformação dos folhelhos• mergulho dos estratos• espessamento das camadas junto à falha no bloco baixo• bandas de deformação Figura 45– Geometria sigmoidal dos depósitos deltaicos do Grupo Ilhas..
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_058
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_043
# -------------------
# [ESTRUTURA_FÍSICA] falha | Observações importantes:• geometria das falhas e das camadas• deformação dos folhelhos• mergulho dos estratos• espessamento das camadas junto à [E] falha [/E] no bloco baixo• bandas de deformação Figura 45– Geometria sigmoidal dos depósitos deltaicos do Grupo Ilhas..
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_058
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_043
# -------------------
# [ESTRUTURA_FÍSICA] maciços | PONTO 14- Lobos sigmoidais e arenitos [E] maciços [/E] da Formação Taquipe( Andar Aratu, Cretáceo Inferior; fig. 47)..
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_023
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_139
# -------------------
# [UNIDADE_LITO] Formação Taquipe | PONTO 14- Lobos sigmoidais e arenitos maciços da [E] Formação Taquipe [/E]( Andar Aratu, Cretáceo Inferior; fig. 47)..
# True URI:  #formacao_328
# Pred URI:  #formacao_242
# -------------------
# [UNIDADE_LITO] Formação Taquipe | Descrição: A [E] Formação Taquipe [/E] representa um depósito de preenchimento de canyon desenvolvido durante uma fase de queda do nível do lago..
# True URI:  #formacao_328
# Pred URI:  #formacao_242
# -------------------
# [ESTRUTURA_FÍSICA] laminações cruzadas | Algumas camadas de arenitos muito finos exibem [E] laminações cruzadas [/E] e outros estratos mostram-se maciços..
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_169
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_139
# -------------------
# [ESTRUTURA_FÍSICA] maciços | Algumas camadas de arenitos muito finos exibem laminações cruzadas e outros estratos mostram-se [E] maciços [/E]..
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_023
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_139
# -------------------
# [ESTRUTURA_FÍSICA] falhas | Essas camadas, localmente cortadas por pequenas [E] falhas [/E] normais( fig. 48), podem ser interpretadas como turbiditos associados a fluxos de detritos remobilizados em frentes deltaicas..
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_058
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_043
# -------------------
# [CAMPO] Campo de Rio do Bu | DANIEL, L. M. F.; SOUZA, E. M.; MATO, L. F. Geoquímica e modelos de migração de hidrocarbonetos no [E] Campo de Rio do Bu [/E]- integração com o Compartimento Nordeste da Bacia do Recôncavo, Bahia..
# True URI:  #CAMP_CD_CAMPO_0830
# Pred URI:  #CAMP_CD_CAMPO_0179
# -------------------
# [ESTRUTURA_FÍSICA] falhas | Luciano Portugal Magnavita nasceu em de agosto de na cidade de Salvador, Bahia. Geólogo graduado pela Universidade de Brasília em 1976 e Doutor pela Universidade de Oxford, Inglaterra, em 1992, ingressou na Petrobras em 1978, tendo trabalhado na interpretação das bacias terrestres e marítimas do estado da Bahia. Após um período junto à área de novos negócios, foi transferido para o Rio de Janeiro em 2002, onde integrou a equipe de interpretação do ativo das bacias de Campos, Espírito Santo e Nordeste do Brasil. Além das atividades profissionais regulares, ministra cursos de Geologia Estrutural em programas da Universidade Petrobras e mantêm atividades acadê-micas como convidado em diversas universidades do País. Geólogo Sênior da Petrobras, foi nomeado Consultor Técnico em 2001 e Consultor Sênior em 2004. Seus principais interesses são a tectônica e sedimentação em bacias do tipo rifte, tectônica salífera e controle de [E] falhas [/E] na acumulação de petróleo. Recentemente foi transferido para a área internacional, trabalhando atualmente em Houston- EUA, na área de novos negócios do Golfo do México..
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_058
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_043
# -------------------
# [UNIDADE_CRONO] Jurássico Tardio | Com base em diferenças nas suas características estratigráficas e/ ou estruturais, a margem continental brasileira pode ser dividida em duas províncias principais:( 1) a província leste- sudeste, estendendo-se da bacia de Pelotas até a bacia Recife- João Pessoa, apresenta um estilo tectônico distensional cujas idades vão do [E] Jurássico Tardio [/E] ao Cretáceo Inicial..
# True URI:  #UpperJurassic
# Pred URI:  #Jurassic
# -------------------
# [UNIDADE_CRONO] Cretáceo Inicial | Com base em diferenças nas suas características estratigráficas e/ ou estruturais, a margem continental brasileira pode ser dividida em duas províncias principais:( 1) a província leste- sudeste, estendendo-se da bacia de Pelotas até a bacia Recife- João Pessoa, apresenta um estilo tectônico distensional cujas idades vão do Jurássico Tardio ao [E] Cretáceo Inicial [/E]..
# True URI:  #LowerCretaceous
# Pred URI:  #Cretaceous
# -------------------
# [ESTRUTURA_FÍSICA] falhas | As estruturas ali presentes acham-se dispostas paralelamente aos alinhamentos estruturais do embasamento pré-cambriano, exceto no segmento do nordeste, onde as [E] falhas [/E] mesozóicas, na bacia Recife- João Pessoa, cortam transversalmente as direções leste- oeste do embasamento..
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_058
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_043
# -------------------
# [UNIDADE_CRONO] Jurássico Tardio | Potiguar até a bacia da Foz do Amazonas, exibe dois estilos tectônicos: um de distensão e outro de compressão, com idades situadas entre o [E] Jurássico Tardio [/E] e o Cretáceo Tardio, com direções que se dis-põem tanto paralelamente aos alinhamentos do embasamento como os cortam transversalmente..
# True URI:  #UpperJurassic
# Pred URI:  #Jurassic
# -------------------
# [UNIDADE_CRONO] Cretáceo Tardio | Potiguar até a bacia da Foz do Amazonas, exibe dois estilos tectônicos: um de distensão e outro de compressão, com idades situadas entre o Jurássico Tardio e o [E] Cretáceo Tardio [/E], com direções que se dis-põem tanto paralelamente aos alinhamentos do embasamento como os cortam transversalmente..
# True URI:  #UpperCretaceous
# Pred URI:  #Cretaceous
# -------------------
# [ESTRUTURA_FÍSICA] fraturas | Hayes e Ewing, limita-dos pela escassez de dados então disponíveis, consideraram essa cadeia como uma feição contínua de provável origem vulcânica e, no aspecto estrutural, independente do sistema de [E] fraturas [/E] do Atlântico Equatorial..
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_059
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_139
# -------------------
# [ESTRUTURA_FÍSICA] fratura | Uma associação dos elementos vulcânicos de Fernando de Noronha e, por extensão, da cadeia na qual elas se situam, com uma zona de [E] fratura [/E] oceânica, foi proposta por Almeida( 1955, 1960, 1965)..
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_059
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_139
# -------------------
# [ESTRUTURA_FÍSICA] fratura | Ainda Almeida, em 1961 e 1965, também postulou a associação dessa cadeia com uma [E] fratura [/E] do assoalho oceânico..
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_059
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_139
# -------------------
# [ESTRUTURA_FÍSICA] fraturas | Sugerimos que essas feições tenham resultado de atividade magmática ao longo de [E] fraturas [/E] no assoalho oceânico..
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_059
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_139
# -------------------
# [ESTRUTURA_FÍSICA] fraturas | Aparentemente esses montes submarinos também se relacionam com os processos que desenvolveram [E] fraturas [/E] morfológicas no talude e sopé continentais, e, localmente, estenderam a sua atividade em áreas emersas..
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_059
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_139
# -------------------
# ...
# True URI:  #CAMP_CD_CAMPO_0364
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_143
# -------------------
# [CAMPO] Tainha | — óleos gerados pelos sedimentos do Andar Alagoas e representados pelas acumulações dos campos, de Atalaia do Sul( poços 4-ATS-1 e 14-SE), Riachuelo, Mato Grosso, Carmópolis( todos os reservatórios), Siririzinho, Castanhal, Tigre, Brejo Grande, Coqueiro Seco, Ta-buleiro dos Martins, Guaricema, Dourado, Camorim( à exceção dos poços 7-CM-22D e 37-SES), Camorim Leste, Mero, [E] Tainha [/E] e Ca-vala e pelos hidrocarbonetos recuperados nos poços 1-IP-2-SE, 1-CAV-1-SE, 1-CAU-3-SE, 1-ATN-1-SE, 1-RPO-1-SE, 1-ALG-1-SE, 9-CG-2-SEX, 1-CAP-1-SE, 1-RR-1-AL, 1-SES-30, 1-SES-63, 1-SES-18A, 1-SES-64, 1-ALS-15, 1-ALS-27, 1-ALS-8 e 1-ALS-3:— óleos resultantes da mistura de hidrocarbonetos gerados nos sedimentos do Neocomiano e do An Fig..
# True URI:  #CAMPO_GENERICO
# Pred URI:  #BASE_CD_BACIA_080
# -------------------
# [POÇO] 1-ALS-8 | — óleos gerados pelos sedimentos do Andar Alagoas e representados pelas acumulações dos campos, de Atalaia do Sul( poços 4-ATS-1 e 14-SE), Riachuelo, Mato Grosso, Carmópolis( todos os reservatórios), Siririzinho, Castanhal, Tigre, Brejo Grande, Coqueiro Seco, Ta-buleiro dos Martins, Guaricema, Dourado, Camorim( à exceção dos poços 7-CM-22D e 37-SES), Camorim Leste, Mero, Tainha e Ca-vala e pelos hidrocarbonetos recuperados nos poços 1-IP-2-SE, 1-CAV-1-SE, 1-CAU-3-SE, 1-ATN-1-SE, 1-RPO-1-SE, 1-ALG-1-SE, 9-CG-2-SEX, 1-CAP-1-SE, 1-RR-1-AL, 1-SES-30, 1-SES-63, 1-SES-18A, 1-SES-64, 1-ALS-15, 1-ALS-27, [E] 1-ALS-8 [/E] e 1-ALS-3:— óleos resultantes da mistura de hidrocarbonetos gerados nos sedimentos do Neocomiano e do An Fig..
# True URI:  #POCO_CD_POCO_007429
# Pred URI:  #POCO_CD_POCO_023091
# -------------------
# [CAMPO] Robalo | dar Alagoas, e representados pelas acumulações dos campos de Anin-gas, Angelim, Caioba, [E] Robalo [/E] e pelos hidrocarbonetos recuperados nos poços 6-PDM-8-SES, 3-PIR-7-AL, 1-SES-19D, 6-CM-37-SES, 7-CM-22D-SES e 4-SES-67..
# True URI:  None
# Pred URI:  #hiloclastite
# -------------------
# [POÇO] poços 6-PDM-8-SES | dar Alagoas, e representados pelas acumulações dos campos de Anin-gas, Angelim, Caioba, Robalo e pelos hidrocarbonetos recuperados nos [E] poços 6-PDM-8-SES [/E], 3-PIR-7-AL, 1-SES-19D, 6-CM-37-SES, 7-CM-22D-SES e 4-SES-67..
# True URI:  #POCO_CD_POCO_007663
# Pred URI:  #POCO_CD_POCO_023091
# -------------------
# [FLUIDODATERRA_i] água doce | Os óleos de origem continental possuem teor percentual de enxofre muito baixo, sempre inferior a 0,05 %, em decorrência da pouca solubilidade do enxofre em [E] água doce [/E]( baixo Eh), ao contrário do que ocorre em águas salgadas( Eh elevado), onde a solubilidade é acentuada( fig. 2)..
# True URI:  #fluid_composition
# Pred URI:  #carbon_dioxide
# -------------------
# [FLUIDODATERRA_i] água doce | Os óleos de origem continental possuem teor percentual de enxofre muito baixo, sempre inferior a 0,05 %, em decorrência da pouca solubilidade do enxofre em [E] água doce [/E]( baixo Eh), ao contrário do que ocorre em águas salgadas( Eh elevado), onde a solubilidade é acentuada( fig. 2)..
# True URI:  #water
# Pred URI:  #carbon_dioxide
# -------------------
# [FLUIDODATERRA_i] água doce | Os óleos de origem continental possuem teor percentual de enxofre muito baixo, sempre inferior a 0,05 %, em decorrência da pouca solubilidade do enxofre em [E] água doce [/E]( baixo Eh), ao contrário do que ocorre em águas salgadas( Eh elevado), onde a solubilidade é acentuada( fig. 2)..
# True URI:  #fluid_composition
# Pred URI:  #carbon_dioxide
# -------------------
# [FLUIDODATERRA_i] águas salgadas | Os óleos de origem continental possuem teor percentual de enxofre muito baixo, sempre inferior a 0,05 %, em decorrência da pouca solubilidade do enxofre em água doce( baixo Eh), ao contrário do que ocorre em [E] águas salgadas [/E]( Eh elevado), onde a solubilidade é acentuada( fig. 2)..
# True URI:  #fluid_composition
# Pred URI:  #fluid_texture
# -------------------
# [FLUIDODATERRA_i] águas salgadas | Os óleos de origem continental possuem teor percentual de enxofre muito baixo, sempre inferior a 0,05 %, em decorrência da pouca solubilidade do enxofre em água doce( baixo Eh), ao contrário do que ocorre em [E] águas salgadas [/E]( Eh elevado), onde a solubilidade é acentuada( fig. 2)..
# True URI:  #water
# Pred URI:  #fluid_texture
# -------------------
# [FLUIDODATERRA_i] águas salgadas | Os óleos de origem continental possuem teor percentual de enxofre muito baixo, sempre inferior a 0,05 %, em decorrência da pouca solubilidade do enxofre em água doce( baixo Eh), ao contrário do que ocorre em [E] águas salgadas [/E]( Eh elevado), onde a solubilidade é acentuada( fig. 2)..
# True URI:  #fluid_composition
# Pred URI:  #fluid_texture
# -------------------
# [FLUIDODATERRA_i] asfaltenos | A distribuição triangular dos componentes dos óleos continentais determinados pela cromatografia líquida mostra que o percentual de compostos polares( resinas+ [E] asfaltenos [/E]) é relativamente baixo, de 7 a 10 %, ao passo que o de parafinas é elevado e varia de 70 a 85 %..
# True URI:  #heavy_oil
# Pred URI:  #carbon_dioxide
# -------------------
# [FLUIDODATERRA_i] asfaltenos | A distribuição triangular dos componentes determinados pela cromatografia líquida mostra que os óleos de origem marinha e/ou evaporítica apresentam teores de resinas+ [E] asfaltenos [/E] em torno de 15 a 35 %, compostos saturados( parafinas) entre 40 e 75 % e compostos aromáticos entre 8 e 25 %( figs. 7 e 8)..
# True URI:  #heavy_oil
# Pred URI:  #carbon_dioxide
# -------------------
# [FLUIDODATERRA_i] asfaltenos | A distribuição triangular dos componentes dos óleos e daqueles determinados pela cromatografia líquida mostra que os óleos provenientes de mistura possuem teores percentuais de compostos altamente polares( resinas + [E] asfaltenos [/E]), que variam entre 7 e 36 %..
# True URI:  #heavy_oil
# Pred URI:  #carbon_dioxide
# -------------------
# [FLUIDODATERRA_i] asfaltenos | O teor de compostos altamente polares( resinas + [E] asfaltenos [/E]) é alto e varia de 22 a 58 %, ao passo que o percentual de compostos parafínicos oscila entre 17 e 50 %, e o de compostos aromáticos varia de 15 a 28 %( fig. 7)..
# True URI:  #heavy_oil
# Pred URI:  #carbon_dioxide
# -------------------
# [FLUIDODATERRA_i] asfaltenos | O percentual de não-hidrocarbonetos( resinas + [E] asfaltenos [/E]) situa-se entre 35 e 70 %( figs. 7 e 10)..
# True URI:  #heavy_oil
# Pred URI:  #carbon_dioxide
# -------------------
# [FLUIDODATERRA_i] óleo | A temperatura, além de poder controlar o tipo de [E] óleo [/E] nos reservatórios e de gerar fluxos hidrodinâmicos, constitui um dos fatores fundamentais para haver geração de hidrocarbonetos..
# True URI:  #oil
# Pred URI:  #carbon_dioxide
# -------------------
# [POÇO] 1-RJS-203 | As áreas mais quentes estão situadas na região norte da bacia— onde os gradientes variam de 44 a 560F / km— e na que se situa entre o Cabo de São Tomé e o Alto Regional de Badejo( área do [E] 1-RJS-203 [/E]), que apresenta gradientes entre 44 e 480F/km..
# True URI:  #POCO_CD_POCO_025532
# Pred URI:  #POCO_CD_POCO_025253
# -------------------
# [CAMPO] campos | situado na faixa de ocorrência da maioria dos [E] campos [/E] de óleo de temperaturas mais elevadas..
# True URI:  #field
# Pred URI:  #CAMP_CD_CAMPO_0519
# -------------------
# [ESTRUTURA_FÍSICA] Falhamento | As feições tectônicas que mais influenciam a distribuição das temperaturas na bacia são:— Baixo de São Tomé;— Alto Regional de Badejo;— [E] Falhamento [/E] limite da Bacia Pré-Aptiana;— Falhamento terciário; — Falhas com direção NW-SE situadas ao norte dos campos de Pargo e de Badejo, possíveis componentes de um sistema tectônico transcorrente..
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_058
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_207
# -------------------
# [ESTRUTURA_FÍSICA] Falhamento | As feições tectônicas que mais influenciam a distribuição das temperaturas na bacia são:— Baixo de São Tomé;— Alto Regional de Badejo;— Falhamento limite da Bacia Pré-Aptiana;— [E] Falhamento [/E] terciário; — Falhas com direção NW-SE situadas ao norte dos campos de Pargo e de Badejo, possíveis componentes de um sistema tectônico transcorrente..
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_058
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_207
# -------------------
# [UNIDADE_LITO] Formação Lagoa Feia | Uma vez que a geração de óleo na bacia ocorre nos sedimentos mais profundos( [E] Formação Lagoa Feia [/E]), houve e há migração de hidrocarbonetos, principalmente através de falhamentos, para os reservatórios em posição mais elevada..
# True URI:  #grupo_05
# Pred URI:  #formacao_113
# -------------------
# [ESTRUTURA_FÍSICA] falhamentos | Uma vez que a geração de óleo na bacia ocorre nos sedimentos mais profundos( Formação Lagoa Feia), houve e há migração de hidrocarbonetos, principalmente através de [E] falhamentos [/E], para os reservatórios em posição mais elevada..
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_058
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_139
# -------------------
# [ESTRUTURA_FÍSICA] falhamentos | Nas figuras 5 e 6, observa-se uma elevação dos gradientes em áreas próximas aos [E] falhamentos [/E] a sudeste nos campos de Namorado e Garoupa..
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_058
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_207
# -------------------
# [ESTRUTURA_FÍSICA] Falhamento | [E] Falhamento [/E] terciário na área do Cabo de São
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_058
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_207
# -------------------
# [ESTRUTURA_FÍSICA] falhamento | Esse [E] falhamento [/E] possui aran-de rejeito, até 1 000 m, na Formação Lagoa Feia..
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_058
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_207
# -------------------
# [UNIDADE_LITO] Formação Lagoa Feia | Esse falhamento possui aran-de rejeito, até 1 000 m, na [E] Formação Lagoa Feia [/E]..
# True URI:  #grupo_05
# Pred URI:  #formacao_113
# -------------------
# [ESTRUTURA_FÍSICA] Fraturas | Terdo em vista o porte e a época relativamente recente dessa estrutura, pode-se con-siderá-la responsável pela transferência de calor por transporte de grandes profundidades para menores, sendo a equalização das tempe-- [E] Fraturas [/E] realizada por correntes de convecção..
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_059
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_139
# -------------------
# [POÇO] 1-RJS-150 | A ocorrência de dleo leve e de gás na área do [E] 1-RJS-150 [/E], situado ao norte desse falhamento, pode ter relação com a migração de fluidos através de seu plano de falha, 2.3)
# True URI:  #POCO_CD_POCO_024135
# Pred URI:  #POCO_CD_POCO_025253
# -------------------
# [ESTRUTURA_FÍSICA] falhamento | A ocorrência de dleo leve e de gás na área do 1-RJS-150, situado ao norte desse [E] falhamento [/E], pode ter relação com a migração de fluidos através de seu plano de falha, 2.3)
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_058
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_207
# -------------------
# [ESTRUTURA_FÍSICA] falha | A ocorrência de dleo leve e de gás na área do 1-RJS-150, situado ao norte desse falhamento, pode ter relação com a migração de fluidos através de seu plano de [E] falha [/E], 2.3)
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_058
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_043
# -------------------
# [ESTRUTURA_FÍSICA] dômica | Proximidade de uma fonte térmica— na área dos poços 1-RJS-150 e 1-RJS-225, ocorrem reflexões intracrustais profundas em seções sísmicas com área de 50 km”, com configuração [E] dômica [/E], cujo ápice está em torno de 8 700 m de profundidade( fig. 8)..
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_120
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_207
# -------------------
# [POÇO] 1-RJS-203 | A área do [E] 1-RJS-203 [/E], por sua vez, está situada entre o falhamento limite da Bacia Pré-Aptiana e o Alto Regional de Badejo, apresentando forma de faixa alongada SW-NE e contendo gradientes geotérmicos que variam de 44 a 48°F/km..
# True URI:  #POCO_CD_POCO_025532
# Pred URI:  #POCO_CD_POCO_025253
# -------------------
# [ESTRUTURA_FÍSICA] falhamento | A área do 1-RJS-203, por sua vez, está situada entre o [E] falhamento [/E] limite da Bacia Pré-Aptiana e o Alto Regional de Badejo, apresentando forma de faixa alongada SW-NE e contendo gradientes geotérmicos que variam de 44 a 48°F/km..
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_058
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_207
# -------------------
# [ESTRUTURA_FÍSICA] falhamento | Essa feição está situada no prolongamento da base do grande [E] falhamento [/E] que limita o Alto Regional de Badejo, a oeste..
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_058
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_207
# -------------------
# [UNIDADE_LITO] Formação Lagoa Feia | Atualmente se admite para a Bacia de Campos geração de óleo em sedimentos da [E] Formação Lagoa Feia [/E], sendo estes 25 000 m..
# True URI:  #grupo_05
# Pred URI:  #formacao_113
# -------------------
# [FLUIDODATERRA_i] óleos | Desse modo, a grande diferenciação observada nos [E] óleos [/E] da bacia é resultante das alterações que ocorrem durante a migração e nos reservatórios, sendo a temperatura o principal fator de determinação do tipo e da intensidade da alteração..
# True URI:  #oil
# Pred URI:  #carbon_dioxide
# -------------------
# [ESTRUTURA_FÍSICA] falhamentos | — Anomalias de temperaturas locais, quando próximas a [E] falhamentos [/E] nos reservatórios, indicam possíveis dutos de migração de óleo..
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_058
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_139
# -------------------
# [ROCHA] carbonatos | — A análise qualitativa dos gradientes intervalares evidencia a alta condutividade térmica dos evaporitos e [E] carbonatos [/E] que apresentam temperaturas relativas baixas..
# True URI:  #carbonatos
# Pred URI:  #Carboniferous
# -------------------
# [POÇO] 1-RJS-203 | anomalias positivas de temperaturas nas áreas do [E] 1-RJS-203 [/E] e norte da bacia..
# True URI:  #POCO_CD_POCO_025532
# Pred URI:  #POCO_CD_POCO_025253
# -------------------
# [ROCHA] rochas vulcanoclásticas | No poço 2-SBST-1-BA foram descritas diversas seqüências litológicas associadas a vulcanismo, incluindo diabásio amigdaloidal, basaltos, tufos e [E] rochas vulcanoclásticas [/E]..
# True URI:  #rock
# Pred URI:  #volcanic_rock
# -------------------
# [ROCHA] gabro | Tanto no poço quanto nos afloramentos da ilha reporta-se a ocorrência de basalto e diabásio com textura mais grosseira( cumulado), preliminarmente interpretado no campo como [E] gabro [/E]..
# True URI:  #gabbro
# Pred URI:  #CAMP_CD_CAMPO_0523
# -------------------
# [ESTRUTURA_FÍSICA] discordâncias | As linhas sísmicas nas proximidades da região de Abrolhos( fig. 7) sugerem a ocorrência de feições compressionais e também registram importantes [E] discordâncias [/E] angulares no Neogeno, relacionadas ao soerguimento na Ilha de Santa Bárbara..
# True URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_036
# Pred URI:  #TEFR_CD_TIPO_EST_FISICA_ROCHA_139
# -------------------
# [FLUIDODATERRA_i] | Todo esse quadro veio a sofrer mudanças na década de 1970, com a descoberta de [E] [/E] petróleo
# True URI:  #oil
# Pred URI:  #carbon_dioxide
# -------------------
# [UNIDADE_CRONO] Campaniano-Maastrichtiano | Convém lem-brar que a identificação do limite [E] Campaniano-Maastrichtiano [/E] não é possível com os métodos de foraminíferos planctônicos e nanofósseis calcários..
# True URI:  #Maastrichtian
# Pred URI:  #Campanian
# -------------------
# Precisão:  0.8582548136009832
# Total dataset teste:  3199
# Total predito:  2441

# %%
#####  Ajustar o código para as URI anotadas no PetroNER

n = 1554

print ('URI: ', teste_ENT_URI[n])
#print ('Entidade: ', entities_teste[n])
#print ('Classe: ', classes_anchor_teste[n])
print ('Sentença: ', teste_text[n])

#lista_intancias = buscar_label(classes_NER_dataset_teste[n])

most_similar = PetroOntoVec.wv.most_similar([embedding_dataset_teste[n]], topn=30)

for m in most_similar:
    if  teste_ENT_URI[n] == m[0][len_name-1:]:
        print ('---------------------------------- \n', m[1], m[0], '\n ----------------------------------')
        
    else:
        #if editdistance.eval(eliminaCaracteresAcentuados(entities_dataset_teste[n]), 
        #                     eliminaCaracteresAcentuados(m[0])) < 3:
        #    print ('---------------------------------- \n', m , '\n ----------------------------------')
        #else:

        #    if m[0] in lista_intancias:
        print (m[1], m[0]) #[len_name-1:]
# Out:
# URI:  #BASE_CD_BACIA_116
# Sentença:  [BACIA] Sergipe | As seções mais completas dessa unidade são conhecidas nas bacias do Recôncavo e de [E] Sergipe [/E]- Alagoas; também foram observadas em amostras de perfurações nas bacias de Camamu- Almada e Espírito Santo..
# ----------------------------------
#  0.9912571907043457 http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#BASE_CD_BACIA_116
#  ----------------------------------
# 0.7794181108474731 terra
# 0.7556122541427612 b'\xb3\x90\xd7\xaa\x82O\xa1\xa5\xbcK\xac\xe7y\x7f\x0b\xc4'
# 0.7538831233978271 b'M\x85\x86k\x9f\xd6y\xbc\xa4\x0f\x83\xc1\xee\x15"\xd6'
# 0.7135032415390015 b'\xe1{f\xc1\xae\xc7u\xf2\x93\x17t\x0e&+\xb2\xbc'
# 0.7110310792922974 b'\xabi\xabu\xb3x\x82\xd1~^\xb4\xb7d\x8a<\xe4'
# 0.6969970464706421 alagoas
# 0.6679792404174805 b'm\x85\x86k\x9f\xd6y\xbc\xa4\x0f\x83\xc1\xee\x15"\xd6'
# 0.663460373878479 b'\xb3\x90\xd7\xaa\x82o\xa1\xa5\xbck\xac\xe7y\x7f\x0b\xc4'
# 0.6558833122253418 b'\xc5\xa2\x95\xebyp\xdc\xb57:\x80\xa8\xb0\xd5\x1dw'
# 0.6552327871322632 b'\x0b\x9e(\xe8\x17\x81\xcee,f\x0er\x05\x93\x15\xab'
# 0.6547820568084717 http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#CAMP_CD_CAMPO_0249
# 0.6542398929595947 b'\xdb]\xa2\x80\xff\xf4\xd9\xf2\x04\xf58\xaf\x0b\x97\xe2\xdb'
# 0.6501806378364563 b'\x8d\x9c\xda\xa12\xb6\xe0\xc2\xfa\xb5o\xce6~\x14<'
# 0.6497688293457031 b'yb\x9f\xe5\xc1\xce\xf5h\x1b\xcd\x85\xa0\xb2\xfb\x8en'
# 0.649621307849884 b'\xbf\xa6:\x10\x10\x11\xde\x9e\xfa\x8e\xe6\x83\x7f\x90\xf2"'
# 0.6486393213272095 b'i\xd3\x8di\n\r\x88\x8a\x12\xe0\xac\xa5\xba\xce\xc7\xfc'
# 0.6480841636657715 b'\xf7r\xb3\xd8\x16\xc07gl\xc3\xd8w\x8c\x94y\xc3'
# 0.6480593681335449 b'|a>\x1b0~\xe3\xd3%]u\xdc\x9b\xce\x81g'
# 0.6474643349647522 b'=Di\xa7\x9b\x1f\xd2\x0b\x8c;\x1e\x08\x8a:4\xdc'
# 0.6471731662750244 9-CP-1524-SE
# 0.6451596617698669 b'\x1f\xcar\x9b-#\xc2\xd8q\x02?\x00\x13\x1c\xa0\x8e'
# 0.6451422572135925 b'p8\xb0\t5\x07\t\xca\xa1n\xc3=\x9b\xe8h\x89'
# 0.6442189812660217 b'\xa7t\x95r\xd7\x16\xd14\xe8\xc6\x99v\xe3\x16&\x93'
# 0.6432093381881714 b"-\x0c\x8bs\xc5\xce'\xe5\xff\xbc\xf8g\xf6\x0b\x01\x1c"
# 0.6428028345108032 b'\xe4\xdc\xb8\xa3\x07)\x07\xf7D/\xb04/n\x11)'
# 0.6417166590690613 b'\x99\xfb\x94\x0c\xcf\xb3\x19\xc5%v\x83\x8f\xb7\xae\xa4\xd0'
# 0.6411155462265015 b'\xd8\xc4\x14\xc5\xff\t\xeb\xd1~\x96\xd9\x86\xdc\x10\xd1\xd9'
# 0.6409359574317932 http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#formacao_130
# 0.6402163505554199 b'_\xfb+o\xa0\x96\xe1\x93v\x04x\xedk.c\xa1'

# %% [markdown]
# Clusterizando os embedins usando uma algoritmo de clusterização por densidade

# %%
# Algoritmo de clusterização
clustering = DBSCAN(eps=alpha, min_samples=2, metric='cosine').fit(embedding_dataset_teste)

# %% [markdown]
# Agora vamos reduzir a dimensionalidade para poder visualizar os vetores

# %%
PCA_dataset_teste = PCA(n_components=2).fit_transform(embedding_dataset_teste)

# %%
fig, ax = plt.subplots(figsize=(20, 20))#, layout='constrained')
#plt.scatter(TSNE_dataset_teste.T[0], TSNE_dataset_teste.T[1], c=clustering.labels_, s=2)
#plt.scatter(TSNE_dataset_treino.T[0], TSNE_dataset_treino.T[1], c=clustering.labels_, s=2)
plt.scatter(PCA_dataset_teste.T[0], PCA_dataset_teste.T[1], c=clustering.labels_, s=2)

#for i in range(len(entities_dataset_teste)):
#    plt.text(x=TSNE_dataset_teste.T[0][i], 
#             y=TSNE_dataset_teste.T[1][i],
#             s='(' + str(clustering.labels_[i]) + ') ' + entities_dataset_teste[i] + ' - ' + str(i), fontdict=dict(size=1),)

#for i in range(len(entities_dataset_treino)):
#    plt.text(x=TSNE_dataset_treino.T[0][i], 
#             y=TSNE_dataset_treino.T[1][i],
#             s='(' + str(clustering.labels_[i]) + ') ' + entities_dataset_treino[i] + ' - ' + str(i), fontdict=dict(size=1),)

for i in range(len(embedding_dataset_teste)):
    plt.text(x=PCA_dataset_teste.T[0][i], 
             y=PCA_dataset_teste.T[1][i],
             #s='(' + str(clustering.labels_[i]) + ') ' + str(i), fontdict=dict(size=1),)
             s='(' + str(clustering.labels_[i]) + ') ' + ' - ' + teste_ENT_URI[i] + ' - ' + str(i), fontdict=dict(size=1),)
    if i > 1000:
        break
    
mpld3.display(fig)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el42799474272363350647252213468"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el42799474272363350647252213468", {"width": 1440.0, "height": 1440.0, "axes": [{"bbox": [0.125, 0.125, 0.775, 0.755], "xlim": [-10.09876561164856, 16.1381094455719], "ylim": [-8.795969653129578, 12.5013019323349], "xdomain": [-10.09876561164856, 16.1381094455719], "ydomain": [-8.795969653129578, 12.5013019323349], "xscale": "linear", "yscale": "linear", "axes": [{"position": "bottom", "nticks": 8, "tickvalues": null, "tickformat_formatter": "", "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": false}, "visible": true}, {"position": "left", "nticks": 11, "tickvalues": null, "tickformat_formatter": "", "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": false}, "visible": true}], "axesbg": "#FFFFFF", "axesbgalpha": null, "zoomable": true, "id": "el4279947427236332488", "lines": [], "paths": [], "markers": [], "texts": [{"text": "(-1)  - #CAMP_CD_CAMPO_0902 - 0", "position": [-3.0158698558807373, -4.127625942230225], "coordinates": "data", "h_anchor": "start", "v_baseline": "auto", "rotation": -0.0, "fontsize": 1.0, "color": "#000000", "alpha": 1, "zorder": 3, "id": "el4279947389564338128"}, {"text": "(0)  - #sandstone - 1", "position": [-0.3003244698047638, -2.9117162227630615], "coordinates": "data", "h_anchor": "start", "v_baseline": "auto", "rotation": -0.0, "fontsize": 1.0, "color": "#000000", "alpha": 1, "zorder": 3, "id": "el4279947389564237248"}, {"text": "(1)  - #membro_010 - 2", "position": [-3.7749528884887695, -0.1592230498790741], "coordinates": "data", "h_anchor": "start", "v_baseline": "auto", "rotation": -0.0, "fontsize": 1.0, "color": "#000000", "alpha": 1, "zorder": 3, "id": "el4279947389564237808"}, {"text": "(2)  - #LowerCretaceous - 3", "position": [-6.006132125854492, 9.159078598022461], "coordinates": "data", "h_anchor": "start", "v_baseline": "auto", "rotation": -0.0, "fontsize": 1.0, "color": "#000000", "alpha": 1, "zorder": 3, "id": "el4279947389564238368"}, {"text": "(3)  - #BASE_CD_BACIA_270 - 4", "position": [-6.537403106689453, -1.6593928337097168], "coordinates": "data", "h_anchor": "start", "v_baseline": "auto", "rotation": -0.0, "fontsize": 1.0, "color": "#000000", "alpha": 1, "zorder": 3, "id": "el4279947389564238928"}, {"text": "(4)  - #hydrocarbon - 5", "position": [11.473119735717773, 0.9732946753501892], "coordinates": "data", "h_anchor": "start", "v_baseline": "auto", "rotation": -0.0, "fontsize": 1.0, "color": "#000000", "alpha": 1, "zorder": 3, "id": "el4279947389564239488"}, {"text": "(5)  - #basin - 6", "position": [-1.5900424718856812, -6.5446696281433105], "coordinates": "data", "h_anchor": "start", "v_baseline": "auto", "rotation": -0.0, "fontsize": 1.0, "color": "#000000", "alpha": 1, "zorder": 3, "id": "el4279947389545488624"}, {"text": "(6)  - #Carboniferous - 7", "position": [-4.604941368103027, 6.6257643699646], "coordinates": "data", "h_anchor": "start", "v_baseline": "auto", "rotation": -0.0, "fontsize": 1.0, "color": "#000000", "alpha": 1, "zorder": 3, "id": "el4279947389545489184"}, {"text": "(7)  - #BASE_CD_BACIA_030 - 8", "position": [-7.6339263916015625, -3.499467134475708], "coordinates": "data", "h_anchor": "start", "v_baseline": "auto", "rotation": -0.0, "fontsize": 1.0, "color": "#000000", "alpha": 1, "zorder": 3, "id": "el4279947389545489744"}, {"text": "(8)  - #CAMP_CD_CAMPO_0760 - 9", "position": [-6.518517017364502, -2.3858938217163086], "coordinates": "data", "h_anchor": "start", "v_baseline": "auto", "rotation": -0.0, "fontsize": 1.0, "color": "#000000", "alpha": 1, "zorder": 3, "id": "el4279947389545490304"}, {"text": "(9)  - #BASE_CD_BACIA_281 - 10", "position": [-6.6514692306518555, -2.4754934310913086], "coordinates": "data", "h_anchor": "start", "v_baseline": "auto", "rotation": -0.0, "fontsize": 1.0, "color": "#000000", "alpha": 1, "zorder": 3, "id": "el4279947389545490864"}, {"text": "(9)  - #BASE_CD_BACIA_281 - 11", "position": [-6.400931358337402, -2.5785470008850098], "coord ...

# %%
ex_1 = 943
ex_2 = 221
print(teste_text[ex_1])
print(teste_text[ex_2])
distance.cosine(embedding_dataset_teste[ex_1], embedding_dataset_teste[ex_2])
# Out:
# [UNIDADE_LITO] Formação Marizal | Uma discordância angular separa a tectono-seqüência do Cretáceo Inferior( Da Silva, 1993) dos depósitos aluviais de conglomerados, arenitos e ocasionais folhelhos e calcários da [E] Formação Marizal [/E], de idade Alagoas..
# [UNIDADE_LITO] Membro Oiteirinhos | Formação Muribeca, [E] Membro Oiteirinhos [/E]..
# 0.6944807171821594

# %%
len(clustering.labels_)
# Out:
# 2116
